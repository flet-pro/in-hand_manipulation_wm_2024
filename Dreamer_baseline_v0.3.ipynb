# %% [markdown]
# 画像

# %%
# %env MUJOCO_GL=egl
# Out:
# env: MUJOCO_GL=egl

# %%
# torch.deviceを定義．この変数は後々モデルやデータをGPUに転送する時にも使います
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# !nvidia-smi
# Out:
# Sun Jan 12 05:27:03 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.77.01              Driver Version: 566.36         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4090        On  |   00000000:01:00.0  On |                  Off |
# |  0%   30C    P8              4W /  450W |     943MiB /  24564MiB |      3%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import gc
import os
import time
from typing import Any, List, Tuple

import gymnasium as gym
import gymnasium_robotics

import matplotlib.pyplot as plt
import numpy as np
# import pybullet_envs  # PyBulletの環境をgymに登録する
import torch
from torch import nn
from torch.distributions import Normal
from torch.distributions.kl import kl_divergence
from torch.nn import functional as F
from torch.nn.utils import clip_grad_norm_
from torch.utils.tensorboard import SummaryWriter
from einops import rearrange
import cv2

import wandb
# 可視化のためにTensorBoardを用いるので，Colab上でTensorBoardを表示するための宣言を行う
# %load_ext tensorboard

# %%
gym.register_envs(gymnasium_robotics)
env = gym.make('HandManipulateEggRotate_BooleanTouchSensorsDense-v1', render_mode="rgb_array", max_episode_steps=100)

observation, info = env.reset(seed=42)
# print(observation['observation'])
for _ in range(5):
    action = env.action_space.sample()  # User-defined policy function
    observation, reward, terminated, truncated, info = env.step(action)
    print(reward)

    img = env.render()
    plt.imshow(img)
    plt.show()
# Out:
# -2.549167133124918
# -2.4532397856471277
# -2.4493528445832653
# -2.4463430075783497
# -2.397746975444275

# %% [markdown]
#  この環境のアクションは、手の各関節の目標角度を指定する連続値のベクトルで構成されています。各要素は対応する関節の目標角度を表し、一般的に-1から1の範囲で正規化されています。これらの値は、実際の関節角度にマッピングされ、手の動作を制御します。(ChatGPT)

# %%
action
# Out:
# array([-0.39736378,  0.95726323, -0.27407295,  0.81049025, -0.15221916,
#        -0.375386  , -0.5852783 , -0.99450475, -0.7689274 , -0.951862  ,
#        -0.13915816, -0.4439047 , -0.34656247, -0.81286687,  0.71482164,
#         0.59372646,  0.4638753 ,  0.48574013,  0.10092324,  0.49836224],
#       dtype=float32)

# %% [markdown]
# 観測（オブザベーション）: 観測は、手の状態、物体の状態、目標状態、そしてタッチセンサーの情報を含むベクトルです。具体的には、以下の情報が含まれます：
#
# - 手の関節角度と速度: 各関節の現在の角度とその変化率。
# - 物体の位置と回転: 操作対象である卵の現在の位置と回転状態。
# - 目標位置と回転: 卵が達成すべき目標の位置と回転状態。
# - タッチセンサーの状態: 各センサーが接触を検出しているかどうかを示すブール値。

# %% [markdown]
# **タッチセンサの状態を表す後半が0となっているため，修正が必要** \
# 考えられる原因
# - 環境がうまく動かせていない（gymnasiumの干渉？）
# - エピソードが途中で終わっている

# %%
observation
# Out:
# {'observation': array([-1.76775256e-01, -2.40664827e-01, -1.72549477e-02,  8.11237486e-01,
#          7.01072057e-01,  8.72360896e-01,  6.02652209e-02,  2.56421534e-01,
#          4.82716671e-01,  7.15706169e-01, -5.14713397e-02,  6.89154400e-01,
#          6.24396852e-01,  5.55694503e-01,  3.09681378e-01, -7.45743668e-02,
#          6.81639448e-01,  8.49767280e-01,  8.29780906e-01, -1.08910754e-01,
#          6.85247844e-01,  4.18937622e-02,  5.52337597e-03, -8.19022418e-01,
#         -4.72156010e-01,  2.58644551e+00, -8.84245026e-01,  5.94502830e+00,
#         -6.48192781e-01, -1.15194927e-02, -1.92706472e+00,  2.43720195e-01,
#         -4.36789547e+00, -7.60383794e-01, -2.16480354e+00, -7.21451899e+00,
#          3.81676441e-01,  2.78661203e-01, -1.34626222e+00, -4.33363357e-01,
#         -5.81695181e+00,  5.32356385e+00,  6.74606620e-04,  7.69720682e+00,
#          1.78899663e+00,  4.76785458e-01,  6.58509145e-01,  4.59879845e+00,
#          6.68997337e-03, -8.19711840e-02,  1.94084757e-01, -5.04784059e-01,
#         -2.37252900e+00,  7.82727998e-01,  1.00624468e+00,  8.73562540e-01,
#          1.60827801e-01,  6.30110988e-01, -7.74736145e-02,  7.08721568e-01,
#          3.07687700e-01,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00]),
#  'achieved_goal': array([ 1.00624468,  0.87356254,  0.1608278 ,  0.63011099, -0.07747361,
#          0.70872157,  0.3076877 ]),
#  'desired_goal': array([ 1.00812643,  0.86879525,  0.16309555,  0.62262971, -0.73337606,
#         -0.09784108, -0.25479191])}

# %% [markdown]
# ### 環境Wrapperを作成

# %%
class GymWrapper(object):
    """
    PyBullet環境のためのラッパー
    """

    metadata = {"render.modes": ["human", "rgb_array"]}
    reward_range = (-np.inf, np.inf)

    # 　同時に画像の大きさも変更できるようにします
    def __init__(
        self,
        env: gym.Env,
        render_width: int = 64,
        render_height: int = 64,
    ) -> None:
        """
        コンストラクタ．

        Parameters
        ----------
        env : gym.Env
            gymで提供されている環境のインスタンス．
        render_width : int
            観測画像の幅．
        render_height : int
            観測画像の高さ．
        """
        self._env = env

        self._render_width = render_width
        self._render_height = render_height

    def __getattr(self, name: str) -> Any:
        """
        環境が保持している属性値を取得するメソッド．

        Parameters
        ----------
        name : str
            取得したい属性値の名前．

        Returns
        -------
        _env.name : Any
            環境が保持している属性値．
        """
        return getattr(self._env, name)

    @property
    def observation_space(self) -> gym.spaces.Box:
        """
        観測空間に関する情報を取得するメソッド．

        Returns
        -------
        space : gym.spaces.Box
            観測空間に関する情報（各画素値の最小値，各画素値の最大値，観測データの形状， データの型）．
        """
        width = self._render_width
        height = self._render_height
        return gym.spaces.Box(0, 255, (height, width, 3), dtype=np.uint8)

    @property
    def action_space(self) -> gym.spaces.Box:
        """
        行動空間に関する情報を取得するメソッド．

        Returns
        -------
        space : gym.spaces.Box
            行動空間に関する情報（各行動の最小値，各行動の最大値，行動空間の次元， データの型） ．
        """
        return self._env.action_space

    # 　元の観測（低次元の状態）は今回は捨てて，env.render()で取得した画像を観測とします.
    #  画像，報酬，終了シグナルが得られます.
    def step(self, action: np.ndarray) -> (np.ndarray, float, bool, dict):
        """
        環境に行動を与え次の観測，報酬，終了フラグを取得するメソッド．

        Parameters
        ----------
        action : np.dnarray (action_dim, )
            与える行動．

        Returns
        -------
        obs : np.ndarray (height, width, 3)
            行動を与えたときの次の観測．
        reward : float
            行動を与えたときに得られる報酬．
        done : bool
            エピソードが終了したかどうか表すフラグ．
        info : dict
            その他の環境に関する情報．
        """
        obs_hand, reward, terminated, truncated, info = self._env.step(action)
        obs = self._env.render()
        obs = cv2.resize(obs, (self._render_height, self._render_width), interpolation=cv2.INTER_LINEAR)
        return obs, obs_hand, reward, terminated, truncated, info

    def reset(self) -> np.ndarray:
        """
        環境をリセットするためのメソッド．

        Returns
        -------
        obs : np.ndarray (height, width, 3)
            環境をリセットしたときの初期の観測．
        """
        obs_hand, info = self._env.reset()
        obs = self._env.render()
        return obs, obs_hand['observation']

    def render(self, **kwargs) -> np.ndarray:
        """
        観測をレンダリングするためのメソッド．

        Parameters
        ----------
        Returns
        -------
        obs : np.ndarray (height, width, 3)
            観測をレンダリングした結果．
        """
        return self._env.render(**kwargs)

    def close(self) -> None:
        """
        環境を閉じるためのメソッド．
        """
        self._env.close()

# %%
class RepeatAction(GymWrapper):
    """
    同じ行動を指定され
    た回数自動的に繰り返すラッパー．観測は最後の行動に対応するものになる
    """

    def __init__(self, env: GymWrapper, skip: int = 4) -> None:
        """
        コンストラクタ．

        Parameters
        ----------
        skip : int
            同じ行動を繰り返す回数．
        """
        # gym.Wrapper.__init__(self, env)
        super().__init__(env, render_width=env._render_width, render_height=env._render_height)
        self._skip = skip

    def reset(self) -> np.ndarray:
        """
        環境をリセットするためのメソッド．

        Returns
        -------
        obs : np.ndarray (width, height, 3)
            環境をリセットしたときの初期の観測．
        obs_hand : np.ndarray (153)
            環境をリセットしたときの初期の観測．         
        """
        obs, obs_hand = self._env.reset()
        obs = cv2.resize(obs, (self._render_height, self._render_width), interpolation=cv2.INTER_LINEAR)
        return obs, obs_hand

    def step(self, action: np.ndarray) -> (np.ndarray, float, bool, dict):
        """
        環境に行動を与え次の観測，報酬，終了フラグを取得するメソッド．
        与えられた行動をskipの回数だけ繰り返した結果を返す．

        Parameters
        ----------
        action : np.ndarray (action_dim, )
            与える行動．

        Returns
        -------
        obs : np.ndarray (width, height, 3)
            行動をskipの回数だけ繰り返したあとの観測．
        total_reawrd : float
            行動をskipの回数だけ繰り返したときの報酬和．
        done : bool
            エピソードが終了したかどうか表すフラグ．
        info : dict
            その他の環境に関する情報．
        """
        total_reward = 0.0
        for _ in range(self._skip):
            obs, obs_hand, reward, terminated, truncated, info = self._env.step(action)
            # obs = cv2.resize(obs, (self._render_height, self._render_width), interpolation=cv2.INTER_LINEAR)
            total_reward += reward
        return obs, obs_hand['observation'], total_reward, terminated, truncated, info

# %%
def make_env() -> RepeatAction:
    """
    作成たラッパーをまとめて適用して環境を作成する関数．

    Returns
    -------
    env : RepeatAction
        ラッパーを適用した環境．
    """
    gym.register_envs(gymnasium_robotics)
    env = gym.make('HandManipulateEggRotate_BooleanTouchSensorsDense-v1', render_mode="rgb_array", max_episode_steps=50)

    # Dreamerでは観測は64x64のRGB画像
    env = GymWrapper(
        env, render_width=64, render_height=64
    )
    env = RepeatAction(env, skip=2)  # DreamerではActionRepeatは2
    return env

# %%
gym.register_envs(gymnasium_robotics)
env = make_env()
env.reset()
for _ in range(5):
    action = env.action_space.sample()  # User-defined policy function
    observation, obs_hand, reward, terminated, truncated, info = env.step(action)
    print("reward", reward)
    print("observation shape", observation.shape)
    print("observation-hand shape", obs_hand.shape)

    img = env.render()
    plt.imshow(img)
    plt.show()
# Out:
# reward -2.8681758708402265
# observation shape (64, 64, 3)
# observation-hand shape (153,)
# reward -2.852992707057725
# observation shape (64, 64, 3)
# observation-hand shape (153,)
# reward -2.6341442992936104
# observation shape (64, 64, 3)
# observation-hand shape (153,)
# reward -2.177790266478773
# observation shape (64, 64, 3)
# observation-hand shape (153,)
# reward -1.9960347328041876
# observation shape (64, 64, 3)
# observation-hand shape (153,)

# %% [markdown]
# ### classの作成

# %%
class TransitionModel(nn.Module):
    """
    状態遷移を担うクラス．このクラスは複数の要素を含んでいます．
    決定的状態遷移 （RNN) : h_t+1 = f(h_t, s_t, a_t)
    確率的状態遷移による1ステップ予測として定義される "prior" : p(s_t+1 | h_t+1)
    観測の情報を取り込んで定義される "posterior": q(s_t+1 | h_t+1, e_t+1)
    """

    def __init__(
        self,
        state_dim: int,
        action_dim: int,
        rnn_hidden_dim: int,
        hidden_dim: int = 200,
        min_stddev: float = 0.1,
        act: "function" = F.elu,
    ) -> None:
        """
        コンストラクタ．

        Parameters
        ----------
        state_dim : int
            確率的状態sの次元数．
        action_dim : int
            行動空間の次元数．
        rnn_hidden_dim : int
            決定的状態遷移を計算するRNNの隠れ層の次元数．
        hidden_dim : int
            決定的状態hの次元数．
        min_stddev : float
            確率状態遷移の標準偏差の最小値．
        act : function
            活性化関数．
        """
        super(TransitionModel, self).__init__()
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.rnn_hidden_dim = rnn_hidden_dim
        self.fc_state_action = nn.Linear(state_dim + action_dim, hidden_dim)

        self.fc_rnn_hidden = nn.Linear(rnn_hidden_dim, hidden_dim)
        self.fc_state_mean_prior = nn.Linear(hidden_dim, state_dim)
        self.fc_state_stddev_prior = nn.Linear(hidden_dim, state_dim)
        self.fc_rnn_hidden_embedded_obs = nn.Linear(rnn_hidden_dim + 1024+153, hidden_dim) # 1024 -> 153に変更
        self.fc_state_mean_posterior = nn.Linear(hidden_dim, state_dim)
        self.fc_state_stddev_posterior = nn.Linear(hidden_dim, state_dim)

        # next hidden stateを計算
        self.rnn = nn.GRUCell(hidden_dim, rnn_hidden_dim)
        self._min_stddev = min_stddev
        self.act = act

    def forward(
        self,
        state: torch.Tensor,
        action: torch.Tensor,
        rnn_hidden: torch.Tensor,
        embedded_next_obs: torch.Tensor,
    ) -> Tuple[torch.Tensor]:
        """
        prior p(s_t+1 | h_t+1) と posterior q(s_t+1 | h_t+1, e_t+1) を返すメソッド．
        この2つが近づくように学習する．

        Parameters
        ----------
        state : torch.Tensor (batch size, state dim)
            時刻tの状態(s_t)．
        action : torch.Tensor (batch size, action dim)
            時刻tの行動(a_t)．
        rnn_hidden : torch.Tensor (batch size, rnn hidden dim)
            RNNが保持している決定的状態(h_t)．
        embedded_next_obs : torch.Tensor (batch size, 1024)
            時刻t+1の観測をエンコードしたもの(e_t+1)．

        Returns
        -------
        next_state_prior : torch.Tensor (batch size, state dim)
            prior(p(s_t+1 | h_t+1))による次の時刻の状態の予測．
        next_state_posterior : torch.Tensor (batch size, state dim)
            posterior(q(s_t+1 | h_t+1, e_t+1))による次の時刻の状態の予測．
        rnn_hidden : torch.Tensor (batch size, rnn hidden dim)
            RNNが保持する次の決定的状態(h_t+1)．
        """
        next_state_prior, rnn_hidden = self.prior(
            self.recurrent(state, action, rnn_hidden)
        )
        next_state_posterior = self.posterior(rnn_hidden, embedded_next_obs)
        return next_state_prior, next_state_posterior, rnn_hidden

    def recurrent(
        self, state: torch.Tensor, action: torch.Tensor, rnn_hidden: torch.Tensor
    ) -> torch.Tensor:
        """
        決定的状態 h_t+1 = f(h_t, s_t, a_t)を計算するメソッド．

        Parameters
        ----------
        state : torch.Tensor (batch size, state dim)
            時刻tの状態(s_t)．
        action : torch.Tensor (batch size, action dim)
            時刻tの行動(a_t)．
        rnn_hidden : torch.Tensor (batch size, rnn hidden dim)
            RNNが保持している決定的状態(h_t)．

        Returns
        -------
        rnn_hidden : torch.Tensor (batch size, rnn hidden dim)
            RNNが保持する次の決定的状態(h_t+1)．
        """
        hidden = self.act(self.fc_state_action(torch.cat([state, action], dim=1)))
        # h_t+1を求める
        rnn_hidden = self.rnn(hidden, rnn_hidden)
        return rnn_hidden

    def prior(self, rnn_hidden: torch.Tensor) -> Tuple[torch.Tensor]:
        """
        prior p(s_t+1 | h_t+1) を計算するメソッド．

        Parameters
        ----------
        rnn_hidden : torch.Tensor (batch size, rnn hidden dim)
            RNNが保持している決定的状態(h_t+1)．

        Returns
        -------
        state : torch.Tensor (batch size, state dim)
            決定的状態を用いてサンプリングされた確率的な状態(s_t+1)．
            ここでは決定的状態h_t+1からガウス分布の平均，標準偏差を推定してサンプリングしています．
        rnn_hidden : torch.Tensor (batch size, rnn hidden dim)
            RNNが保持する決定的状態(h_t+1)．
            入力からのものをそのまま返しています．
        """
        #h_t+1を求める（ヒント: self.act, self.fc_rnn_hiddenを使用）
        hidden = self.act(self.fc_rnn_hidden(rnn_hidden)) # WRITE ME

        mean = self.fc_state_mean_prior(hidden)
        stddev = F.softplus(self.fc_state_stddev_prior(hidden)) + self._min_stddev
        return Normal(mean, stddev), rnn_hidden

    def posterior(
        self, rnn_hidden: torch.Tensor, embedded_obs: torch.Tensor
    ) -> torch.Tensor:
        """
        posterior q(s_t+1 | h_t+1, e_t+1)  を計算するメソッド．

        Parameters
        ----------
        rnn_hidden : torch.Tensor (batch size, rnn hidden dim)
            RNNが保持している決定的状態(h_t+1)．
        embedded_obs : torch.Tensor (batch size, 1024)
            時刻t+1の観測をエンコードしたもの．

        Returns
        -------
        state : torch.Tensor (batch size, state dim)
            決定的状態とエンコードした観測を用いてサンプリングされた確率的な状態(s_t+1)．
            ここでは決定的状態h_t+1とエンコードした観測e_t+1からガウス分布の平均，標準偏差を推定してサンプリングしています．
        """
        # h_t+1，o_t+1を結合し，q(s_t+1 | h_t+1, e_t+1) を計算する
        # print("rnn_hidden shape: ", rnn_hidden.shape)
        # print("rnn_hidden dtype: ", rnn_hidden.dtype)
        # print("embedded_obs shape: ", embedded_obs.shape)
        # print("embedded_obs dtype: ", embedded_obs.dtype)
        hidden = self.act(self.fc_rnn_hidden_embedded_obs(torch.cat([rnn_hidden, embedded_obs], dim=1))) # WRITE ME
        mean = self.fc_state_mean_posterior(hidden)
        stddev = F.softplus(self.fc_state_stddev_posterior(hidden)) + self._min_stddev
        return Normal(mean, stddev)

# %%
class ObservationModel(nn.Module):
    """
    p(o_t | s_t, h_t)
    低次元の状態表現から画像を再構成するデコーダ (3, 64, 64)
    """

    def __init__(self, state_dim: int, rnn_hidden_dim: int) -> None:
        """
        コンストラクタ．

        Parameters
        ----------
        state_dim : int
            確率的状態sの次元数．
        rnn_hidden_dim : int
            決定的状態hの次元数．
        """
        super(ObservationModel, self).__init__()
        self.fc = nn.Linear(state_dim + rnn_hidden_dim, 1024)
        self.dc1 = nn.ConvTranspose2d(1024, 128, kernel_size=5, stride=2)
        self.dc2 = nn.ConvTranspose2d(128, 64, kernel_size=5, stride=2)
        self.dc3 = nn.ConvTranspose2d(64, 32, kernel_size=6, stride=2)
        self.dc4 = nn.ConvTranspose2d(32, 3, kernel_size=6, stride=2)

    def forward(self, state: torch.Tensor, rnn_hidden: torch.Tensor) -> torch.Tensor:
        """
        順伝播を行うメソッド．確率的状態sと決定的状態hから観測を再構成する．

        Parameters
        ----------
        state : torch.Tensor (batch size, state dim)
            確率的状態s．
        rnn_hidden : torch.Tensor (batch size, rnn_hidden_dim)
            決定的状態h．

        Returns
        -------
        obs : torch.Tensor (batch size, 3, 64, 64)
            再構成された観測o．
        """
        hidden = self.fc(torch.cat([state, rnn_hidden], dim=1))
        hidden = hidden.view(hidden.size(0), 1024, 1, 1)
        hidden = F.relu(self.dc1(hidden))
        hidden = F.relu(self.dc2(hidden))
        hidden = F.relu(self.dc3(hidden))
        obs = self.dc4(hidden)
        return obs

# %%
class RewardModel(nn.Module):
    """
    p(r_t | s_t, h_t)
    低次元の状態表現から報酬を予測する．
    """

    def __init__(
        self,
        state_dim: int,
        rnn_hidden_dim: int,
        hidden_dim: int = 400,
        act: "function" = F.elu,
    ) -> None:
        """
        コンストラクタ．

        Parameters
        ----------
        state_dim : int
            確率的状態sの次元数．
        rnn_hidden_dim : int
            決定的状態hの次元数．
        hidden_dim : int
            報酬モデルの隠れ層の次元数． (default=400)
        act : function
            報酬モデルに利用される活性化関数． (default=torch.nn.functional.elu)
        """
        super(RewardModel, self).__init__()
        self.fc1 = nn.Linear(state_dim + rnn_hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, 1)
        self.act = act

    def forward(self, state: torch.Tensor, rnn_hidden: torch.Tensor) -> torch.Tensor:
        """
        順伝播を行うメソッド．確率的状態sと決定的状態hから報酬rを推定する．

        Parameters
        ----------
        state : torch.Tensor (batch size, state dim)
            確率的状態s．
        rnn_hidden : torch.Tensor (batch size, rnn_hidden_dim)
            決定的状態h．

        Returns
        -------
        reward : torch.Tensor (batch size, 1)
            確率的状態s，決定的状態hに対する報酬r．
        """
        hidden = self.act(self.fc1(torch.cat([state, rnn_hidden], dim=1)))
        hidden = self.act(self.fc2(hidden))
        hidden = self.act(self.fc3(hidden))
        reward = self.fc4(hidden)
        return reward

# %%
class RSSM:
    """
    TransitionModel, ObservationModel, RewardModelの3つをまとめたRSSMクラス．
    """

    def __init__(
        self,
        state_dim: int,
        action_dim: int,
        rnn_hidden_dim: int,
    ) -> None:
        """
        コンストラクタ．

        Parameters
        ----------
        state_dim : int
            確率的状態sの次元数．
        action_dim : int
            行動空間の次元数．
        rnn_hidden_dim : int
            決定的状態hの次元数．
        """
        self.transition = TransitionModel(state_dim, action_dim, rnn_hidden_dim).to(
            device
        )
        self.observation = ObservationModel(
            state_dim,
            rnn_hidden_dim,
        ).to(device)
        self.reward = RewardModel(
            state_dim,
            rnn_hidden_dim,
        ).to(device)

# %%
# こちらはDQNのReplayBufferの定義
class ReplayBuffer:
    """
    これまでの経験をためておくリプレイバッファ．
    """

    def __init__(self, memory_size: int) -> None:
        """
        コンストラクタ．

        Parameters
        ----------
        memory_size : int
            リプレイバッファに貯められるデータの上限．
        """
        self.memory_size = memory_size
        # 収集する経験は上限を決め古いものから削除する．
        self.memory = deque([], maxlen=memory_size)

    def append(self, transition: dict) -> None:
        """
        環境から得た経験（状態，行動，次の状態，報酬，終了フラグ）をキューに追加するメソッド．
        dequeを用いているため上限(memory_size)に達すると古いものが削除される．

        Parameters
        ----------
        trainsition : dict
            状態(state)，次の状態(next_state)，報酬(reward)，行動(action)，終了フラグ(done)を格納した辞書．
        """
        self.memory.append(transition)

    def sample(self, batch_size: int) -> dict:  # 貯めた経験の中からランダムにミニバッチ単位で経験を取り出す．
        """
        バッファに貯めた経験の中からランダムにミニバッチ単位で経験を取り出すメソッド．

        Parameters
        ----------
        batch_size : int
            バッチサイズ．

        Returns
        -------
        sample : dict
            状態(states)，次の状態(next_states)，報酬(rewards)，行動(actions)，終了フラグ(dones)をバッチサイズ分だけ格納した辞書．
        """
        batch_indexes = np.random.randint(0, len(self.memory), size=batch_size)
        states = np.array([self.memory[index]["state"] for index in batch_indexes])
        next_states = np.array(
            [self.memory[index]["next_state"] for index in batch_indexes]
        )
        rewards = np.array([self.memory[index]["reward"] for index in batch_indexes])
        actions = np.array([self.memory[index]["action"] for index in batch_indexes])
        dones = np.array([self.memory[index]["terminated"] for index in batch_indexes])
        return {
            "states": states,
            "next_states": next_states,
            "rewards": rewards,
            "actions": actions,
            "dones": terminated,
        }

# %%
# 　今回のReplayBuffer
class ReplayBuffer(object):
    """
    RNNを用いて訓練するのに適したリプレイバッファ．
    """

    def __init__(
        self, capacity: int, observation_shape: List[int], observation_hand_shape: List[int], action_dim: int
    ) -> None:
        """
        コンストラクタ．

        Parameters
        ----------
        capacity : int
            リプレイバッファにためておくことができる経験の上限．
        observation_shape : List[int]
            環境から与えられる観測の形状．
        action_dim : int
            行動空間の次元数．
        """
        self.capacity = capacity

        self.observations = np.zeros((capacity, *observation_shape), dtype=np.uint8)
        self.observations_hand = np.zeros((capacity, *observation_hand_shape), dtype=np.uint8)
        self.actions = np.zeros((capacity, action_dim), dtype=np.float32)
        self.rewards = np.zeros((capacity, 1), dtype=np.float32)
        self.done = np.zeros((capacity, 1), dtype=bool)
        # self.done = np.zeros((capacity, 1), dtype=np.bool)

        self.index = 0
        self.is_filled = False

    def push(
        self, observation: np.ndarray, observation_hand: np.ndarray, action: np.ndarray, reward: float, done: bool
    ) -> None:
        """
        リプレイバッファに経験を追加するメソッド．

        Parameters
        ----------
        observation : np.ndarray (64, 64, 3)
            環境から得られた観測．
        observation_hand : np.ndarray (153)
            環境から得られた観測．
        action : np.ndarray (action_dim, )
            エージェントがとった（もしくは経験を貯める際のランダムな）行動．
        reward : float
            観測に対して行動をとったときに得られる報酬．
        done : bool
            エピソードが終了するかどうかのフラグ．
        """
        self.observations[self.index] = observation
        self.observations_hand[self.index] = observation_hand
        self.actions[self.index] = action
        self.rewards[self.index] = reward
        self.done[self.index] = done

        # indexは巡回し，最も古い経験を上書きする
        if self.index == self.capacity - 1:
            self.is_filled = True
        self.index = (self.index + 1) % self.capacity

    def sample(self, batch_size: int, chunk_length: int) -> Tuple[np.ndarray]:
        """
        経験をリプレイバッファからサンプルします．（ほぼ）一様なサンプルです．
        結果として返ってくるのは観測（画像），行動，報酬，終了シグナルについての(batch_size, chunk_length, 各要素の次元)の配列です．
        各バッチは連続した経験になっています．
        注意: chunk_lengthをあまり大きな値にすると問題が発生する場合があります．

        Parameters
        ----------
        batch_size : int
            バッチサイズ．
        chunk_length : int
            バッチあたりの系列長．


        Returns
        -------
        sampled_observations : np.ndarray (batch size, chunk length, 3, 64, 64)
            バッファからサンプリングされた観測．
        sampled_observations_hand : np.ndarray (batch size, chunk length, 153)
            バッファからサンプリングされた観測．
        sampled_actions : np.ndarray (batch size, chunk length, action dim)
            バッファからサンプリングされた行動．
        sampled_rewards : np.ndarray (batch size, chunk length, 1)
            バッファからサンプリングされた報酬．
        sampled_rewards : np.ndarray (batch size, chunk length, 1)
            バッファからサンプリングされたエピソードの終了フラグ．
        """
        episode_borders = np.where(self.done)[0]
        sampled_indexes = []
        for _ in range(batch_size):
            cross_border = True
            while cross_border:
                initial_index = np.random.randint(len(self) - chunk_length + 1)
                final_index = initial_index + chunk_length - 1
                cross_border = np.logical_and(
                    initial_index <= episode_borders, episode_borders < final_index
                ).any()  # 論理積
            sampled_indexes += list(range(initial_index, final_index + 1))

        sampled_observations = self.observations[sampled_indexes].reshape(
            batch_size, chunk_length, *self.observations.shape[1:]
        )
        sampled_observations_hand = self.observations_hand[sampled_indexes].reshape(
            batch_size, chunk_length, *self.observations_hand.shape[1:]
        )
        sampled_actions = self.actions[sampled_indexes].reshape(
            batch_size, chunk_length, self.actions.shape[1]
        )
        sampled_rewards = self.rewards[sampled_indexes].reshape(
            batch_size, chunk_length, 1
        )
        sampled_done = self.done[sampled_indexes].reshape(batch_size, chunk_length, 1)
        return sampled_observations, sampled_observations_hand, sampled_actions, sampled_rewards, sampled_done

    def __len__(self) -> int:
        """
        バッファに貯められている経験の数を返すメソッド．

        Returns
        -------
        length : int
            バッファに貯められている経験の数．
        """
        return self.capacity if self.is_filled else self.index

# %% [markdown]
# 次に観測の前処理を行う関数を実装します．ちなみに，これもラッパーとして最初から適用してしまわないのは，リプレイバッファにはより容量の小さなnp．uint8の形式で保存しておきたいためです．

# %%
def preprocess_obs(obs: np.ndarray) -> np.ndarray:
    """
    画像を正規化する．[0, 255] -> [-0.5, 0.5]．

    Parameters
    ----------
    obs : np.ndarray (64, 64, 3) or (chank length, batch size, 64, 64, 3)
        環境から得られた観測．画素値は[0, 255]．

    Returns
    -------
    normalized_obs : np.ndarray (64, 64, 3) or (chank length, batch size, 64, 64, 3)
        画素値を[-0.5, 0.5]で正規化した観測．
    """
    obs = obs.astype(np.float32)
    normalized_obs = obs / 255.0 - 0.5
    return normalized_obs

# %% [markdown]
# Dreamerでは価値関数の学習を行いますが，このために通常のTD誤差ではなく，**TD(λ)をベースにしたλ-return**としてターゲット価値を計算し，それと現在の予測価値の誤差を用います．そのためにλ-returnを計算する関数をここで実装しておきます．

# %%
def lambda_target(
    rewards: torch.Tensor, values: torch.Tensor, gamma: float, lambda_: float
) -> torch.Tensor:
    """
    価値関数の学習のためのλ-returnを計算する関数．

    Parameters
    ----------
    rewards : torch.Tensor (imagination_horizon, batch size * (chank length - 1))
        報酬モデルによる報酬の推定値．
    values : torch.Tensor (imagination_horizon, batch size * (chank length - 1))
        価値関数を近似するValueモデルによる状態価値観数の推定値．
    gamma : float
        割引率．
    lambda_ : float
        λ-returnのパラメータλ．

    V_lambda : torch.Tensor (imagination_horizon, batch size * (chank length - 1))
        各状態に対するλ-returnの値．
    """
    V_lambda = torch.zeros_like(rewards, device=rewards.device)

    H = rewards.shape[0] - 1
    V_n = torch.zeros_like(rewards, device=rewards.device)
    V_n[H] = values[H]
    for n in range(1, H + 1):
        # まずn-step returnを計算します
        # 注意: 系列が途中で終わってしまったら，可能な中で最大のnを用いたn-stepを使います
        V_n[:-n] = (gamma**n) * values[n:]
        for k in range(1, n + 1):
            if k == n:
                V_n[:-n] += (gamma ** (n - 1)) * rewards[k:]
            else:
                V_n[:-n] += (gamma ** (k - 1)) * rewards[k : -n + k]

        # lambda_でn-step returnを重みづけてλ-returnを計算します
        if n == H:
            V_lambda += (lambda_ ** (H - 1)) * V_n
        else:
            V_lambda += (1 - lambda_) * (lambda_ ** (n - 1)) * V_n

    return V_lambda

# %%
class Encoder(nn.Module):
    """
    (3, 64, 64)の画像を(1024,)のベクトルに変換し，ロボットハンドの観測環境（153,）と連結を行うエンコーダクラス．
    """

    def __init__(self) -> None:
        """
        コンストラクタ．
        層の定義のみを行う．
        """
        super(Encoder, self).__init__()
        self.cv1 = nn.Conv2d(3, 32, kernel_size=4, stride=2)
        self.cv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.cv3 = nn.Conv2d(64, 128, kernel_size=4, stride=2)
        self.cv4 = nn.Conv2d(128, 256, kernel_size=4, stride=2)

    def forward(self, obs: torch.Tensor, obs_hand: torch.Tensor) -> torch.Tensor:
        """
        順伝播を行うメソッド．観測画像をベクトルに埋め込む．

        Parameters
        ----------
        obs : torch.Tensor (batch size, 3, 64, 64)
            環境から得られた観測画像．

        Returns
        -------
        embedded_obs : torch.Tensor (batch size, 1024+153)
            観測を1024+153次元のベクトルに埋め込んだもの．
        """
        hidden = F.relu(self.cv1(obs))
        hidden = F.relu(self.cv2(hidden))
        hidden = F.relu(self.cv3(hidden))
        embedded_obs = F.relu(self.cv4(hidden)).reshape(hidden.size(0), -1)
        # print("embedded_obs shape: ", embedded_obs.shape)
        # print("obs_hand shape: ", obs_hand.shape)
        embedded_obs = torch.cat([embedded_obs, obs_hand], dim=-1)
        return embedded_obs

# %%
class ValueModel(nn.Module):
    """
    低次元の状態表現(state_dim + rnn_hidden_dim)から状態価値を出力するクラス．
    """

    def __init__(
        self,
        state_dim: int,
        rnn_hidden_dim: int,
        hidden_dim: int = 400,
        act: "function" = F.elu,
    ) -> None:
        """
        コンストラクタ．

        Parameters
        ----------
        state_dim : int
            確率的状態sの次元数．
        rnn_hidden_dim : int
            決定的状態hの次元数．
        hidden_dim : int
            モデルの隠れ層の次元数． (default=400)
        act : function
            モデルの活性化関数． (default=torch.nn.functional.elu)
        """
        super(ValueModel, self).__init__()
        self.fc1 = nn.Linear(state_dim + rnn_hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, 1)
        self.act = act

    def forward(self, state: torch.Tensor, rnn_hidden: torch.Tensor) -> torch.Tensor:
        """
        順伝播を行うメソッド．低次元の状態表現から状態価値を推定する．

        Parameters
        ----------
        state : torch.Tensor (batch size, state dim)
            確率的状態s．
        rnn_hidden : torch.Tensor (batch size, rnn_hidden_dim)
            決定的状態h．

        Returns
        -------
        state_value : torch.Tensor (batch size, 1)
            入力された状態に対する状態価値の推定値．
        """
        hidden = self.act(self.fc1(torch.cat([state, rnn_hidden], dim=1)))
        hidden = self.act(self.fc2(hidden))
        hidden = self.act(self.fc3(hidden))
        state_value = self.fc4(hidden)
        return state_value

# %%
class ActionModel(nn.Module):
    """
    低次元の状態表現(state_dim + rnn_hidden_dim)から行動を計算するクラス．
    """

    def __init__(
        self,
        state_dim: int,
        rnn_hidden_dim: int,
        action_dim: int,
        hidden_dim: int = 400,
        act: "function" = F.elu,
        min_stddev: float = 1e-4,
        init_stddev: float = 5.0,
    ) -> None:
        """
        コンストラクタ．

        Parameters
        ----------
        state_dim : int
            確率的状態sの次元数．
        rnn_hidden_dim : int
            決定的状態hの次元数．
        action_dim : int
            行動空間の次元数．
        hidden_dim : int
            モデルの隠れ層の次元数． (default=400)
        act : function
            モデルの活性化関数． (default=torch.nn.functional.elu)
        min_stddev : float
            行動をサンプリングする分布の標準偏差の最小値． (default=1e-4)
        init_stddev : float
            行動をサンプリングする分布の標準偏差の初期値． (default=5.0)
        """
        super(ActionModel, self).__init__()
        self.fc1 = nn.Linear(state_dim + rnn_hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, hidden_dim)
        self.fc_mean = nn.Linear(hidden_dim, action_dim)
        self.fc_stddev = nn.Linear(hidden_dim, action_dim)
        self.act = act
        self.min_stddev = min_stddev
        self.init_stddev = np.log(np.exp(init_stddev) - 1)

    def forward(
        self, state: torch.Tensor, rnn_hidden: torch.Tensor, training: bool = True
    ) -> None:
        """
        順伝播を行うメソッド．入力された状態に対する行動を出力する．
        training=Trueなら，NNのパラメータに関して微分可能な形の行動のサンプル（Reparametrizationによる）を返す．
        training=Falseなら，行動の確率分布の平均値を返す．

        Parameters
        ----------
        staet : torch.Tensor (batch size, state dim)
            確率的状態s．
        rnn_hidden : torch.Tensor (batch size, rnn_hidden_dim)
            決定的状態h．
        training : bool
            訓練か推論かを示すフラグ． (default=True)

        Returns
        -------
        action : torch.Tensor (batch size, action dim)
            入力された状態に対する行動．
            training=Trueでは微分可能な形の行動をサンプリングした値，
            training=Falseでは行動の確率分布の平均値を返す．
        """
        hidden = self.act(self.fc1(torch.cat([state, rnn_hidden], dim=1)))
        hidden = self.act(self.fc2(hidden))
        hidden = self.act(self.fc3(hidden))
        hidden = self.act(self.fc4(hidden))

        # Dreamerの実装に合わせて少し平均と分散に対する簡単な変換が入っています
        mean = self.fc_mean(hidden)
        mean = 5.0 * torch.tanh(mean / 5.0)
        stddev = self.fc_stddev(hidden)
        stddev = F.softplus(stddev + self.init_stddev) + self.min_stddev

        if training:
            action = torch.tanh(Normal(mean, stddev).rsample())  # 微分可能にするためrsample()
        else:
            action = torch.tanh(mean)
        return action

# %%
class Agent:
    """
    ActionModelに基づき行動を決定する．そのためにRSSMを用いて状態表現をリアルタイムで推論して維持するクラス．
    """

    def __init__(self, encoder: Encoder, rssm: RSSM, action_model: ActionModel) -> None:
        """
        コンストラクタ．

        Parameters
        ----------
        encoder : Encoder
            上で定義したEncoderクラスのインスタンス．
            観測画像を1024次元のベクトルに埋め込む ．
        rssm : RSSM
            上で定義したRSSMクラスのインスタンス．
            遷移モデル，1024次元のベクトルを観測画像にするデコーダ，報酬を予測するモデルを持つ．
        action_model : ActionModel
            上で定義したActionModelのインスタンス．
            低次元の状態表現から行動を予測する．
        """
        self.encoder = encoder
        self.rssm = rssm
        self.action_model = action_model

        self.device = next(self.action_model.parameters()).device
        self.rnn_hidden = torch.zeros(1, rssm.rnn_hidden_dim, device=self.device)

    def __call__(self, obs: np.ndarray, obs_hand: np.ndarray, training=True) -> np.ndarray:
        """
        特殊メソッド．
        インスタンスに直接引数を渡すことで実行される．
        （例）agent = Agent(*args)
             action = agent(obs)  # このときに__call__メソッドが呼び出される．

        Parameters
        ----------
        obs : np.ndarray (batch size, 3, 64, 64)
            環境から得られた観測画像．
        training : bool
            訓練か推論かを示すフラグ． (default=True)

        Returns
        -------
        action : np.ndarray (batch size, action dim)
            入力された観測に対する行動の予測．
        """
        # preprocessを適用，PyTorchのためにChannel-Firstに変換
        obs = preprocess_obs(obs)
        obs = torch.as_tensor(obs, device=self.device)
        # print("obs shape: ", obs.shape)
        obs = obs.transpose(1, 2).transpose(0, 1).unsqueeze(0)

        obs_hand = torch.as_tensor(obs_hand, device=self.device).unsqueeze(0)

        with torch.no_grad():
            # 観測を低次元の表現に変換し，posteriorからのサンプルをActionModelに入力して行動を決定する
            embedded_obs = self.encoder(obs, obs_hand).to(torch.float32)
            state_posterior = self.rssm.posterior(self.rnn_hidden, embedded_obs)
            state = state_posterior.sample()
            action = self.action_model(state, self.rnn_hidden, training=training)

            # 次のステップのためにRNNの隠れ状態を更新しておく
            _, self.rnn_hidden = self.rssm.prior(
                self.rssm.recurrent(state, action, self.rnn_hidden)
            )

        return action.squeeze().cpu().numpy()

    def reset(self) -> None:
        """
        RNNの隠れ状態（=決定的状態）をリセットする．
        """
        self.rnn_hidden = torch.zeros(1, self.rssm.rnn_hidden_dim, device=self.device)

# %%
# リプレイバッファの宣言
buffer_capacity = 1000000  # Colabのメモリの都合上，元の実装より小さめにとっています
replay_buffer = ReplayBuffer(
    capacity=buffer_capacity,
    observation_shape=(64,64,3),
    observation_hand_shape=(153,),
    action_dim=env.action_space.shape[0],
)

# モデルの宣言
state_dim = 30  # 確率的状態の次元
rnn_hidden_dim = 200  # 決定的状態（RNNの隠れ状態）の次元
# 確率的状態の次元と決定的状態（RNNの隠れ状態）の次元は一致しなくて良い
encoder = Encoder().to(device)
rssm = RSSM(
    state_dim,
    env.action_space.shape[0],
    rnn_hidden_dim,
)
value_model = ValueModel(state_dim, rnn_hidden_dim).to(device)
action_model = ActionModel(state_dim, rnn_hidden_dim, env.action_space.shape[0]).to(
    device
)

# オプティマイザの宣言
model_lr = 6e-4  # encoder, rssm, obs_model, reward_modelの学習率
value_lr = 8e-5
action_lr = 8e-5
eps = 1e-4
model_params = (
    list(encoder.parameters())
    + list(rssm.transition.parameters())
    + list(rssm.observation.parameters())
    + list(rssm.reward.parameters())
)
model_optimizer = torch.optim.Adam(model_params, lr=model_lr, eps=eps)
value_optimizer = torch.optim.Adam(value_model.parameters(), lr=value_lr, eps=eps)
action_optimizer = torch.optim.Adam(action_model.parameters(), lr=action_lr, eps=eps)

# その他ハイパーパラメータ
seed_episodes = 10  # 最初にランダム行動で探索するエピソード数
all_episodes = 200  # 学習全体のエピソード数（300ほどで，ある程度収束します） 300に変更
max_episodes = 50 # 一回のエピソードでのアクション回数
test_interval = 10  # 何エピソードごとに探索ノイズなしのテストを行うか
model_save_interval = 20  # NNの重みを何エピソードごとに保存するか
collect_interval = 100  # 何回のNNの更新ごとに経験を集めるか（＝1エピソード経験を集めるごとに何回更新するか）

action_noise_var = 0.3  # 探索ノイズの強さ

batch_size = 50
chunk_length = 50  # 1回の更新で用いる系列の長さ
imagination_horizon = 15  # Actor-Criticの更新のために，Dreamerで何ステップ先までの想像上の軌道を生成するか


gamma = 0.9  # 割引率
lambda_ = 0.95  # λ-returnのパラメータ
clip_grad_norm = 100  # gradient clippingの値
free_nats = 3  # KL誤差（RSSMのTransitionModelにおけるpriorとposteriorの間の誤差）がこの値以下の場合，無視する

# %%
replay_buffer.index
# Out:
# 0

# %%
from tqdm.notebook import tqdm
env = make_env()
for episode in tqdm(range(seed_episodes)):
    obs, obs_hand = env.reset()
    terminated = False
    for i in range(max_episodes): # max_episodesの数だけ繰り返してエピソードを集める
        action = env.action_space.sample()
        next_obs, next_obs_hand, reward, terminated, truncated, _ = env.step(action)
        replay_buffer.push(obs, obs_hand, action, reward, terminated)
        obs = next_obs
        obs_hand = next_obs_hand
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
import wandb
# Weights & Biases の初期化

# 設定辞書オブジェクトを定義する
config = {
    "buffer_capacity": buffer_capacity,
    "seed_episodes": seed_episodes,
    "all_episodes": all_episodes,
    "max_episodes": max_episodes,
    "test_interval": test_interval,
    "model_save_interval": model_save_interval,
    "collect_interval": collect_interval,
    "action_noise_var": action_noise_var,
    "batch_size": batch_size,
    "chunk_length": chunk_length,
    "imagination_horizon": imagination_horizon,
    "gamma": gamma,
    "lambda_": lambda_,
    "clip_grad_norm": clip_grad_norm,
    "free_nats": free_nats,
}

wandb.init(project="HandManipulateEgg", name="20250112_img_and_observation", config=config)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tki256 (mie-univ). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/mnt/wandb/run-20250112_053544-ihs0h50m</code>
# Syncing run <strong><a href='https://wandb.ai/mie-univ/HandManipulateEgg/runs/ihs0h50m' target="_blank">20250112_img_and_observation</a></strong> to <a href='https://wandb.ai/mie-univ/HandManipulateEgg' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mie-univ/HandManipulateEgg' target="_blank">https://wandb.ai/mie-univ/HandManipulateEgg</a>
#  View run at <a href='https://wandb.ai/mie-univ/HandManipulateEgg/runs/ihs0h50m' target="_blank">https://wandb.ai/mie-univ/HandManipulateEgg/runs/ihs0h50m</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/mie-univ/HandManipulateEgg/runs/ihs0h50m?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
log_dir = "logs-img_and_hand-20250112"
writer = SummaryWriter(log_dir)

# %%
for episode in range(seed_episodes, all_episodes):
    # -----------------------------
    #      経験を集める
    # -----------------------------
    start = time.time()
    # 行動を決定するためのエージェントを宣言
    policy = Agent(encoder, rssm.transition, action_model)
    env = make_env()
    obs, obs_hand = env.reset()
    done = False
    total_reward = 0
    # while not done:
    for i in range(max_episodes): #合っているのか？
        action = policy(obs, obs_hand)
        # 探索のためにガウス分布に従うノイズを加える(explaration noise)
        action += np.random.normal(0, np.sqrt(action_noise_var),
                                     env.action_space.shape[0])
        next_obs, next_obs_hand, reward, terminated, truncated, _ = env.step(action)
    
        #リプレイバッファに観測，行動，報酬，doneを格納
        replay_buffer.push(obs, obs_hand, action, reward, terminated)
        # print(len(replay_buffer))
        
        obs = next_obs
        obs_hand = next_obs_hand
        total_reward += reward

    # 訓練時の報酬と経過時間をログとして表示
    writer.add_scalar('total reward at train', total_reward, episode)
    print('episode [%4d/%4d] is collected. Total reward is %f' %
            (episode+1, all_episodes, total_reward))
    print('elasped time for interaction: %.2fs' % (time.time() - start))

    # NNのパラメータを更新する
    start = time.time()
    for update_step in range(collect_interval):
        # -------------------------------------------------------------------------------------
        #  RSSM(trainsition_model, obs_model, reward_model)の更新 - Dynamics learning
        # -------------------------------------------------------------------------------------
        observations, observations_hand, actions, rewards, _ = \
            replay_buffer.sample(batch_size, chunk_length)

        # 観測を前処理し，RNNを用いたPyTorchでの学習のためにTensorの次元を調整
        observations = preprocess_obs(observations)
        observations = torch.as_tensor(observations, device=device)  # (B, T, H, W, C)
        observations_hand = torch.as_tensor(observations_hand, device=device)  # (B, T, H, W, C)
        actions = torch.as_tensor(actions, device=device)  # (B, T, action dim)
        rewards = torch.as_tensor(rewards, device=device)  # (B, T, 1)

        observations = rearrange(observations, "b t h w c -> t b c h w")  # (T, B, C, H< W)
        actions = rearrange(actions, "b t d -> t b d")  # (T, B, action dim)
        rewards = rearrange(rewards, "b t d -> t b d")  # (T, B, 1)

        # 観測をエンコーダで低次元のベクトルに変換(一次元にした後にロボットハンドの観測環境ベクトルと結合)
        embedded_observations = encoder(
            observations.reshape(-1, 3, 64, 64), observations_hand.reshape(-1, 153)).view(chunk_length, batch_size, -1)  # (T, B, 1024)

        # 低次元の状態表現を保持しておくためのTensorを定義
        states = torch.zeros(chunk_length, batch_size, state_dim, device=device)  # (T, B, state dim)
        rnn_hiddens = torch.zeros(chunk_length, batch_size, rnn_hidden_dim, device=device)  # (T, B, rnn hidden dim)

        # 低次元の状態表現は最初はゼロ初期化（timestep１つ分）
        state = torch.zeros(batch_size, state_dim, device=device)
        rnn_hidden = torch.zeros(batch_size, rnn_hidden_dim, device=device)

        # 状態s_tの予測を行ってそのロスを計算する（priorとposteriorの間のKLダイバージェンス）
        kl_loss = 0
        for l in range(chunk_length-1):
            next_state_prior, next_state_posterior, rnn_hidden = \
                rssm.transition(state, actions[l], rnn_hidden, embedded_observations[l+1])
            state = next_state_posterior.rsample()
            states[l+1] = state
            rnn_hiddens[l+1] = rnn_hidden
            kl = kl_divergence(next_state_prior, next_state_posterior).sum(dim=1) # WRITE ME （ヒント: kl_divergence()を使用）
            kl_loss += kl.clamp(min=free_nats).mean()  # 原論文通り，KL誤差がfree_nats以下の時は無視
        kl_loss /= (chunk_length - 1)

        # states[0] and rnn_hiddens[0]はゼロ初期化なので以降では使わない
        # states，rnn_hiddensは低次元の状態表現
        states = states[1:]  # (T-1, B, state dim)
        rnn_hiddens = rnn_hiddens[1:]  # (T-1, B, rnn hidden dim)

        # 観測を再構成，また，報酬を予測
        flatten_states = states.view(-1, state_dim)  # ((T-1) x B, state dim)
        flatten_rnn_hiddens = rnn_hiddens.view(-1, rnn_hidden_dim)  # ((T-1) x B, rnn hidden dim)
        recon_observations = rssm.observation(flatten_states, flatten_rnn_hiddens).view(chunk_length-1, batch_size, 3, 64, 64)  # (T-1, B, C, H, W)
        predicted_rewards = rssm.reward(flatten_states, flatten_rnn_hiddens).view(chunk_length-1, batch_size, 1)  # (T-1, B, 1)

        # 観測と報酬の予測誤差を計算
        obs_loss = 0.5 * F.mse_loss(recon_observations, observations[1:], reduction='none').mean([0, 1]).sum()
        reward_loss = 0.5 * F.mse_loss(predicted_rewards, rewards[:-1])

        # 以上のロスを合わせて勾配降下で更新する
        model_loss = kl_loss + obs_loss + reward_loss
        model_optimizer.zero_grad()
        model_loss.backward()
        clip_grad_norm_(model_params, clip_grad_norm)
        model_optimizer.step()

        # --------------------------------------------------
        #  Action Model, Value　Modelの更新　- Behavior learning
        # --------------------------------------------------
        # Actor-Criticのロスで他のモデルを更新することはないので勾配の流れを一度遮断
        # flatten_states, flatten_rnn_hiddensは RSSMから得られた低次元の状態表現を平坦化した値
        flatten_states = flatten_states.detach()
        flatten_rnn_hiddens = flatten_rnn_hiddens.detach()

        # DreamerにおけるActor-Criticの更新のために，現在のモデルを用いた
        # 数ステップ先の未来の状態予測を保持するためのTensorを用意
        imagined_states = torch.zeros(imagination_horizon + 1,
                                         *flatten_states.shape,
                                          device=flatten_states.device)  # (horizon + 1, (T-1) x B, state dim)
        imagined_rnn_hiddens = torch.zeros(imagination_horizon + 1,
                                                *flatten_rnn_hiddens.shape,
                                                device=flatten_rnn_hiddens.device)  # (horizon + 1, (T-1) x B, rnn hidden dim)

        #　未来予測をして想像上の軌道を作る前に，最初の状態としては先ほどモデルの更新で使っていた
        # リプレイバッファからサンプルされた観測データを取り込んだ上で推論した状態表現を使う
        imagined_states[0] = flatten_states
        imagined_rnn_hiddens[0] = flatten_rnn_hiddens

        # open-loopで未来の状態予測を使い，想像上の軌道を作る
        for h in range(1, imagination_horizon + 1):
            # 行動はActionModelで決定．この行動はモデルのパラメータに対して微分可能で,
            #　これを介してActionModelは更新される
            actions = action_model(flatten_states, flatten_rnn_hiddens)  # ((T-1) x B, action dim)
            flatten_states_prior, flatten_rnn_hiddens = rssm.transition.prior(rssm.transition.recurrent(flatten_states,
                                                                   actions,
                                                                   flatten_rnn_hiddens))
            flatten_states = flatten_states_prior.rsample()
            imagined_states[h] = flatten_states  # ((T-1) x B, state dim)
            imagined_rnn_hiddens[h] = flatten_rnn_hiddens  # ((T-1) x B, rnn hidden dim)

        # RSSMのreward_modelにより予測された架空の軌道に対する報酬を計算
        flatten_imagined_states = imagined_states.view(-1, state_dim)  # ((hotizon+1)x(T-1)xB, state dim)
        flatten_imagined_rnn_hiddens = imagined_rnn_hiddens.view(-1, rnn_hidden_dim)  # ((horizon+1)x(T-1)xB, rnn hidden dim)
        imagined_rewards = \
            rssm.reward(flatten_imagined_states,
                        flatten_imagined_rnn_hiddens).view(imagination_horizon + 1, -1)  # ((horizon+1), (T-1)xB, state dim)
        imagined_values = \
            value_model(flatten_imagined_states,
                        flatten_imagined_rnn_hiddens).view(imagination_horizon + 1, -1)  # ((horizon+1), (T-1)xB, rnn hidden dim)

        # λ-returnのターゲットを計算(V_{\lambda}(s_{\tau})
        # lambda_target_values  # WRITE ME （ヒント: lambda_target()を利用）  # ((horizon+1), (T-1)xB, 1)
        lambda_target_values = lambda_target(imagined_rewards, imagined_values, gamma, lambda_)

        # 価値関数の予測した価値が大きくなるようにActionModelを更新
        # PyTorchの基本は勾配降下だが，今回は大きくしたいので-1をかける
        action_loss = -lambda_target_values.mean()
        action_optimizer.zero_grad()
        action_loss.backward()
        clip_grad_norm_(action_model.parameters(), clip_grad_norm)
        action_optimizer.step()

        # TD(λ)ベースの目的関数で価値関数を更新（価値関数のみを学習するため，学習しない変数のグラフは切っている．)
        imagined_values = value_model(flatten_imagined_states.detach(), flatten_imagined_rnn_hiddens.detach()).view(imagination_horizon + 1, -1)# ((horizon+1), (T-1)xB, 1)
        # value_loss = # WRITE ME （ヒント: 0.5 * F.mse_loss()を使用）
        value_loss = 0.5 * F.mse_loss(imagined_values, lambda_target_values.detach())
        value_optimizer.zero_grad()
        value_loss.backward()
        clip_grad_norm_(value_model.parameters(), clip_grad_norm)
        value_optimizer.step()

        # ログをTensorBoardに出力
        print('update_step: %3d model loss: %.5f, kl_loss: %.5f, '
             'obs_loss: %.5f, reward_loss: %.5f, '
             'value_loss: %.5f action_loss: %.5f'
                % (update_step + 1, model_loss.item(), kl_loss.item(),
                    obs_loss.item(), reward_loss.item(),
                    value_loss.item(), action_loss.item()))
        total_update_step = episode * collect_interval + update_step
        writer.add_scalar('model loss', model_loss.item(), total_update_step)
        writer.add_scalar('kl loss', kl_loss.item(), total_update_step)
        writer.add_scalar('obs loss', obs_loss.item(), total_update_step)
        writer.add_scalar('reward loss', reward_loss.item(), total_update_step)
        writer.add_scalar('value loss', value_loss.item(), total_update_step)
        writer.add_scalar('action loss', action_loss.item(), total_update_step)

        # wandb にログを記録
        wandb.log({
            'update_step': total_update_step,
            'model_loss': model_loss.item(),
            'kl_loss': kl_loss.item(),
            'obs_loss': obs_loss.item(),
            'reward_loss': reward_loss.item(),
            'value_loss': value_loss.item(),
            'action_loss': action_loss.item()
        })
    print('elasped time for update: %.2fs' % (time.time() - start))

    # --------------------------------------------------------------
    #    テストフェーズ．探索ノイズなしでの性能を評価する
    # --------------------------------------------------------------
    if (episode + 1) % test_interval == 0:
        policy = Agent(encoder, rssm.transition, action_model)
        start = time.time()
        obs, obs_hand = env.reset()
        done = False
        total_reward = 0
        # while not done:

        for i in range(max_episodes):
            action = policy(obs, obs_hand, training=False)
            obs, obs_hand, reward, terminated, truncated, _ = env.step(action)
            total_reward += reward

        writer.add_scalar('total reward at test', total_reward, episode)
        print('Total test reward at episode [%4d/%4d] is %f' %
                (episode+1, all_episodes, total_reward))
        print('elasped time for test: %.2fs' % (time.time() - start))

    if (episode + 1) % model_save_interval == 0:
        # 定期的に学習済みモデルのパラメータを保存する
        model_log_dir = os.path.join(log_dir, 'episode_%04d' % (episode + 1))
        os.makedirs(model_log_dir, exist_ok=True)
        torch.save(encoder.state_dict(), os.path.join(model_log_dir, 'encoder.pth'))
        torch.save(rssm.transition.state_dict(), os.path.join(model_log_dir, 'rssm.pth'))
        torch.save(rssm.observation.state_dict(), os.path.join(model_log_dir, 'obs_model.pth'))
        torch.save(rssm.reward.state_dict(), os.path.join(model_log_dir, 'reward_model.pth'))
        torch.save(value_model.state_dict(), os.path.join(model_log_dir, 'value_model.pth'))
        torch.save(action_model.state_dict(), os.path.join(model_log_dir, 'action_model.pth'))
    del env
    gc.collect()

writer.close()
# Out:
# episode [  11/ 200] is collected. Total reward is -385.189355
# elasped time for interaction: 2.04s
# update_step:   1 model loss: 5584.40527, kl_loss: 5181.54004, obs_loss: 381.92462, reward_loss: 20.94039, value_loss: 0.00950 action_loss: 0.10766
# update_step:   2 model loss: 2580.82544, kl_loss: 2199.10864, obs_loss: 363.04065, reward_loss: 18.67609, value_loss: 0.03241 action_loss: 0.22855
# update_step:   3 model loss: 1486.72998, kl_loss: 1130.78528, obs_loss: 339.73096, reward_loss: 16.21374, value_loss: 0.08345 action_loss: 0.38069
# update_step:   4 model loss: 856.94128, kl_loss: 532.38788, obs_loss: 307.62534, reward_loss: 16.92811, value_loss: 0.18841 action_loss: 0.57597
# update_step:   5 model loss: 534.38885, kl_loss: 236.91280, obs_loss: 282.08871, reward_loss: 15.38732, value_loss: 0.37632 action_loss: 0.81797
# update_step:   6 model loss: 388.51889, kl_loss: 118.46973, obs_loss: 258.58197, reward_loss: 11.46720, value_loss: 0.74822 action_loss: 1.14291
# update_step:   7 model loss: 312.72012, kl_loss: 74.06882, obs_loss: 229.84875, reward_loss: 8.80254, value_loss: 1.54321 action_loss: 1.61391
# update_step:   8 model loss: 270.52682, kl_loss: 59.67167, obs_loss: 205.91760, reward_loss: 4.93757, value_loss: 3.51587 action_loss: 2.39074
# update_step:   9 model loss: 252.92183, kl_loss: 57.35201, obs_loss: 192.23926, reward_loss: 3.33057, value_loss: 7.24366 action_loss: 3.36621
# update_step:  10 model loss: 235.46173, kl_loss: 56.12562, obs_loss: 175.59750, reward_loss: 3.73861, value_loss: 9.57747 action_loss: 3.88276
# update_step:  11 model loss: 223.15315, kl_loss: 55.15036, obs_loss: 163.99435, reward_loss: 4.00843, value_loss: 10.21398 action_loss: 4.07525
# update_step:  12 model loss: 213.12656, kl_loss: 54.82772, obs_loss: 155.11102, reward_loss: 3.18780, value_loss: 9.14442 action_loss: 3.94299
# update_step:  13 model loss: 197.47871, kl_loss: 52.38044, obs_loss: 142.42529, reward_loss: 2.67299, value_loss: 8.87235 action_loss: 3.96709
# update_step:  14 model loss: 188.04831, kl_loss: 49.36831, obs_loss: 136.25742, reward_loss: 2.42257, value_loss: 11.77505 action_loss: 4.59993
# update_step:  15 model loss: 177.16856, kl_loss: 46.77328, obs_loss: 127.58879, reward_loss: 2.80648, value_loss: 20.96120 action_loss: 6.08999
# update_step:  16 model loss: 167.09300, kl_loss: 43.49661, obs_loss: 121.26562, reward_loss: 2.33076, value_loss: 41.28725 action_loss: 8.46817
# update_step:  17 model loss: 157.91968, kl_loss: 39.64587, obs_loss: 116.45830, reward_loss: 1.81552, value_loss: 79.94716 action_loss: 11.78584
# update_step:  18 model loss: 149.38863, kl_loss: 35.97047, obs_loss: 110.99480, reward_loss: 2.42336, value_loss: 116.38151 action_loss: 14.37894
# update_step:  19 model loss: 140.19756, kl_loss: 32.12275, obs_loss: 105.69895, reward_loss: 2.37585, value_loss: 129.91418 action_loss: 15.49256
# update_step:  20 model loss: 132.14943, kl_loss: 28.95068, obs_loss: 101.51105, reward_loss: 1.68770, value_loss: 145.42783 action_loss: 16.75852
# update_step:  21 model loss: 123.85854, kl_loss: 25.66052, obs_loss: 96.34921, reward_loss: 1.84880, value_loss: 158.60587 action_loss: 17.84934
# update_step:  22 model loss: 116.62412, kl_loss: 22.99978, obs_loss: 91.62099, reward_loss: 2.00335, value_loss: 183.60040 action_loss: 19.47492
# update_step:  23 model loss: 110.17401, kl_loss: 20.17891, obs_loss: 87.98539, reward_loss: 2.00971, value_loss: 230.48131 action_loss: 21.96728
# update_step:  24 model loss: 103.99147, kl_loss: 17.92338, obs_loss: 84.47906, reward_loss: 1.58903, value_loss: 303.02621 action_loss: 25.19431
# update_step:  25 model loss: 99.09367, kl_loss: 15.75371, obs_loss: 81.52881, reward_loss: 1.81115, value_loss: 366.23376 action_loss: 27.79262
# update_step:  26 model loss: 94.41246, kl_loss: 14.00862, obs_loss: 78.40733, reward_loss: 1.99651, value_loss: 372.36191 action_loss: 28.35889
# update_step:  27 model loss: 90.45180, kl_loss: 12.61236, obs_loss: 76.25544, reward_loss: 1.58399, value_loss: 351.16797 action_loss: 28.01808
# update_step:  28 model loss: 87.29581, kl_loss: 11.34732, obs_loss: 73.67323, reward_loss: 2.27526, value_loss: 280.22644 action_loss: 25.82886
# update_step:  29 model loss: 83.01685, kl_loss: 10.04076, obs_loss: 71.18733, reward_loss: 1.78875, value_loss: 247.56383 action_loss: 24.95088
# update_step:  30 model loss: 79.80503, kl_loss: 8.99530, obs_loss: 68.95634, reward_loss: 1.85339, value_loss: 263.36139 action_loss: 26.03495
# update_step:  31 model loss: 76.94481, kl_loss: 7.99532, obs_loss: 67.19094, reward_loss: 1.75854, value_loss: 286.67685 action_loss: 27.41781
# update_step:  32 model loss: 75.15884, kl_loss: 7.15586, obs_loss: 66.17337, reward_loss: 1.82961, value_loss: 317.24637 action_loss: 29.04363
# update_step:  33 model loss: 72.57525, kl_loss: 6.41104, obs_loss: 64.56215, reward_loss: 1.60207, value_loss: 333.42975 action_loss: 30.14209
# update_step:  34 model loss: 70.48517, kl_loss: 5.82987, obs_loss: 62.78530, reward_loss: 1.87001, value_loss: 326.19385 action_loss: 30.44920
# update_step:  35 model loss: 71.43652, kl_loss: 5.26607, obs_loss: 64.20272, reward_loss: 1.96774, value_loss: 304.32086 action_loss: 30.22709
# update_step:  36 model loss: 66.78174, kl_loss: 4.89343, obs_loss: 60.41391, reward_loss: 1.47440, value_loss: 278.18835 action_loss: 29.82779
# update_step:  37 model loss: 69.35014, kl_loss: 4.49829, obs_loss: 63.30712, reward_loss: 1.54473, value_loss: 255.58206 action_loss: 29.55774
# update_step:  38 model loss: 68.45007, kl_loss: 4.20184, obs_loss: 62.31452, reward_loss: 1.93371, value_loss: 235.64255 action_loss: 29.39256
# update_step:  39 model loss: 64.66252, kl_loss: 4.05379, obs_loss: 59.23002, reward_loss: 1.37872, value_loss: 228.75577 action_loss: 29.79286
# update_step:  40 model loss: 63.46820, kl_loss: 3.89338, obs_loss: 58.18552, reward_loss: 1.38931, value_loss: 231.76341 action_loss: 30.61047
# update_step:  41 model loss: 63.36827, kl_loss: 3.77289, obs_loss: 57.98000, reward_loss: 1.61538, value_loss: 231.24249 action_loss: 31.30242
# update_step:  42 model loss: 62.96851, kl_loss: 3.65333, obs_loss: 57.33467, reward_loss: 1.98051, value_loss: 223.29605 action_loss: 31.71008
# update_step:  43 model loss: 60.47863, kl_loss: 3.65447, obs_loss: 55.20929, reward_loss: 1.61487, value_loss: 219.14790 action_loss: 32.31329
# update_step:  44 model loss: 60.87288, kl_loss: 3.63060, obs_loss: 55.50323, reward_loss: 1.73905, value_loss: 229.25914 action_loss: 33.52131
# update_step:  45 model loss: 59.34011, kl_loss: 3.58951, obs_loss: 53.90850, reward_loss: 1.84209, value_loss: 213.31534 action_loss: 33.62759
# update_step:  46 model loss: 58.50310, kl_loss: 3.61120, obs_loss: 53.16356, reward_loss: 1.72834, value_loss: 193.81329 action_loss: 33.56160
# update_step:  47 model loss: 58.73954, kl_loss: 3.60133, obs_loss: 53.25238, reward_loss: 1.88583, value_loss: 182.63516 action_loss: 33.84942
# update_step:  48 model loss: 57.47827, kl_loss: 3.61855, obs_loss: 52.12836, reward_loss: 1.73136, value_loss: 173.06412 action_loss: 34.20652
# update_step:  49 model loss: 57.41219, kl_loss: 3.54972, obs_loss: 51.93604, reward_loss: 1.92643, value_loss: 163.73526 action_loss: 34.56177
# update_step:  50 model loss: 57.07607, kl_loss: 3.52814, obs_loss: 51.68151, reward_loss: 1.86642, value_loss: 157.44655 action_loss: 35.14203
# update_step:  51 model loss: 56.50810, kl_loss: 3.50089, obs_loss: 51.30303, reward_loss: 1.70418, value_loss: 159.96901 action_loss: 36.12505
# update_step:  52 model loss: 56.07525, kl_loss: 3.49391, obs_loss: 50.85191, reward_loss: 1.72942, value_loss: 157.40253 action_loss: 36.92324
# update_step:  53 model loss: 54.73754, kl_loss: 3.51264, obs_loss: 49.77617, reward_loss: 1.44873, value_loss: 153.82428 action_loss: 37.66870
# update_step:  54 model loss: 55.31395, kl_loss: 3.48805, obs_loss: 50.02382, reward_loss: 1.80209, value_loss: 148.51440 action_loss: 38.30278
# update_step:  55 model loss: 54.51041, kl_loss: 3.47652, obs_loss: 49.40517, reward_loss: 1.62872, value_loss: 142.01839 action_loss: 38.87623
# update_step:  56 model loss: 54.59645, kl_loss: 3.48054, obs_loss: 49.37949, reward_loss: 1.73643, value_loss: 148.66107 action_loss: 40.21280
# update_step:  57 model loss: 54.08287, kl_loss: 3.49909, obs_loss: 48.73620, reward_loss: 1.84758, value_loss: 138.47455 action_loss: 40.60425
# update_step:  58 model loss: 54.08410, kl_loss: 3.44554, obs_loss: 48.88518, reward_loss: 1.75338, value_loss: 117.40878 action_loss: 40.39811
# update_step:  59 model loss: 53.66969, kl_loss: 3.44958, obs_loss: 48.51157, reward_loss: 1.70854, value_loss: 106.04216 action_loss: 40.74846
# update_step:  60 model loss: 52.54648, kl_loss: 3.44451, obs_loss: 47.45306, reward_loss: 1.64890, value_loss: 101.35139 action_loss: 41.43976
# update_step:  61 model loss: 53.29811, kl_loss: 3.39714, obs_loss: 47.87711, reward_loss: 2.02385, value_loss: 86.48699 action_loss: 41.54560
# update_step:  62 model loss: 52.56480, kl_loss: 3.39742, obs_loss: 47.30598, reward_loss: 1.86141, value_loss: 85.56796 action_loss: 42.49789
# update_step:  63 model loss: 51.95877, kl_loss: 3.45954, obs_loss: 46.90832, reward_loss: 1.59091, value_loss: 95.34151 action_loss: 44.28482
# update_step:  64 model loss: 52.22811, kl_loss: 3.39973, obs_loss: 47.24494, reward_loss: 1.58344, value_loss: 109.39186 action_loss: 46.38452
# update_step:  65 model loss: 51.55648, kl_loss: 3.36077, obs_loss: 46.40428, reward_loss: 1.79143, value_loss: 105.36344 action_loss: 47.34760
# update_step:  66 model loss: 51.88654, kl_loss: 3.39219, obs_loss: 46.69009, reward_loss: 1.80426, value_loss: 83.95116 action_loss: 47.05897
# update_step:  67 model loss: 51.58517, kl_loss: 3.35546, obs_loss: 46.27972, reward_loss: 1.94999, value_loss: 58.28348 action_loss: 46.15852
# update_step:  68 model loss: 51.04969, kl_loss: 3.38264, obs_loss: 46.06514, reward_loss: 1.60190, value_loss: 45.34347 action_loss: 46.05669
# update_step:  69 model loss: 51.10937, kl_loss: 3.38427, obs_loss: 46.05789, reward_loss: 1.66721, value_loss: 37.77906 action_loss: 46.42472
# update_step:  70 model loss: 51.32380, kl_loss: 3.36884, obs_loss: 46.01682, reward_loss: 1.93813, value_loss: 37.77752 action_loss: 47.72689
# update_step:  71 model loss: 51.10694, kl_loss: 3.34936, obs_loss: 45.76107, reward_loss: 1.99651, value_loss: 37.06815 action_loss: 48.96607
# update_step:  72 model loss: 50.97481, kl_loss: 3.37218, obs_loss: 45.79152, reward_loss: 1.81111, value_loss: 42.06645 action_loss: 50.97741
# update_step:  73 model loss: 50.28260, kl_loss: 3.34464, obs_loss: 45.16592, reward_loss: 1.77205, value_loss: 43.68852 action_loss: 52.60979
# update_step:  74 model loss: 49.65364, kl_loss: 3.34279, obs_loss: 44.82097, reward_loss: 1.48988, value_loss: 44.77394 action_loss: 54.14758
# update_step:  75 model loss: 49.42863, kl_loss: 3.33141, obs_loss: 44.71979, reward_loss: 1.37743, value_loss: 44.58232 action_loss: 55.61164
# update_step:  76 model loss: 50.48450, kl_loss: 3.32915, obs_loss: 45.29943, reward_loss: 1.85591, value_loss: 31.80047 action_loss: 55.42343
# update_step:  77 model loss: 50.17017, kl_loss: 3.31698, obs_loss: 45.03107, reward_loss: 1.82211, value_loss: 24.33054 action_loss: 55.44986
# update_step:  78 model loss: 49.70267, kl_loss: 3.31863, obs_loss: 44.81577, reward_loss: 1.56827, value_loss: 20.42354 action_loss: 55.94273
# update_step:  79 model loss: 49.84440, kl_loss: 3.28913, obs_loss: 45.09441, reward_loss: 1.46086, value_loss: 18.95025 action_loss: 56.52045
# update_step:  80 model loss: 49.36731, kl_loss: 3.28227, obs_loss: 44.53062, reward_loss: 1.55442, value_loss: 18.55369 action_loss: 57.38324
# update_step:  81 model loss: 49.76962, kl_loss: 3.30387, obs_loss: 44.75946, reward_loss: 1.70628, value_loss: 19.00246 action_loss: 58.42580
# update_step:  82 model loss: 48.97405, kl_loss: 3.28325, obs_loss: 44.04850, reward_loss: 1.64229, value_loss: 19.04592 action_loss: 59.62360
# update_step:  83 model loss: 48.98137, kl_loss: 3.29632, obs_loss: 44.05415, reward_loss: 1.63090, value_loss: 18.72050 action_loss: 60.56886
# update_step:  84 model loss: 49.76724, kl_loss: 3.28672, obs_loss: 44.83611, reward_loss: 1.64440, value_loss: 17.98045 action_loss: 61.32339
# update_step:  85 model loss: 49.20722, kl_loss: 3.27535, obs_loss: 44.11145, reward_loss: 1.82042, value_loss: 17.53209 action_loss: 61.59967
# update_step:  86 model loss: 48.61802, kl_loss: 3.27887, obs_loss: 44.16055, reward_loss: 1.17861, value_loss: 16.48529 action_loss: 62.22541
# update_step:  87 model loss: 48.70932, kl_loss: 3.28524, obs_loss: 43.93037, reward_loss: 1.49371, value_loss: 15.72862 action_loss: 62.66718
# update_step:  88 model loss: 48.67485, kl_loss: 3.28540, obs_loss: 43.68409, reward_loss: 1.70536, value_loss: 14.89569 action_loss: 62.70016
# update_step:  89 model loss: 48.99121, kl_loss: 3.27679, obs_loss: 44.07227, reward_loss: 1.64215, value_loss: 13.94637 action_loss: 62.76184
# update_step:  90 model loss: 48.51228, kl_loss: 3.27437, obs_loss: 43.51548, reward_loss: 1.72242, value_loss: 12.96150 action_loss: 62.52931
# update_step:  91 model loss: 48.44388, kl_loss: 3.24918, obs_loss: 43.72836, reward_loss: 1.46634, value_loss: 11.99223 action_loss: 61.95811
# update_step:  92 model loss: 48.60855, kl_loss: 3.26303, obs_loss: 43.62967, reward_loss: 1.71586, value_loss: 11.11717 action_loss: 61.21479
# update_step:  93 model loss: 48.23156, kl_loss: 3.25588, obs_loss: 43.42236, reward_loss: 1.55332, value_loss: 11.47618 action_loss: 60.01600
# update_step:  94 model loss: 48.32893, kl_loss: 3.23630, obs_loss: 43.61762, reward_loss: 1.47501, value_loss: 11.13889 action_loss: 59.18283
# update_step:  95 model loss: 48.30194, kl_loss: 3.22788, obs_loss: 43.36950, reward_loss: 1.70456, value_loss: 10.00802 action_loss: 58.75026
# update_step:  96 model loss: 47.03247, kl_loss: 3.22524, obs_loss: 42.50230, reward_loss: 1.30494, value_loss: 8.19121 action_loss: 58.82911
# update_step:  97 model loss: 48.66486, kl_loss: 3.22374, obs_loss: 43.53721, reward_loss: 1.90391, value_loss: 7.32836 action_loss: 59.24659
# update_step:  98 model loss: 47.84954, kl_loss: 3.21899, obs_loss: 42.93936, reward_loss: 1.69118, value_loss: 8.00790 action_loss: 59.51480
# update_step:  99 model loss: 48.42344, kl_loss: 3.19463, obs_loss: 43.60742, reward_loss: 1.62138, value_loss: 9.34488 action_loss: 59.91249
# update_step: 100 model loss: 48.93521, kl_loss: 3.21269, obs_loss: 43.72469, reward_loss: 1.99783, value_loss: 8.55819 action_loss: 59.47535
# elasped time for update: 21.10s
# episode [  12/ 200] is collected. Total reward is -157.287673
# elasped time for interaction: 1.79s
# update_step:   1 model loss: 49.81435, kl_loss: 3.29114, obs_loss: 44.62027, reward_loss: 1.90293, value_loss: 6.27298 action_loss: 58.44638
# update_step:   2 model loss: 48.74081, kl_loss: 3.22178, obs_loss: 43.72028, reward_loss: 1.79876, value_loss: 5.19153 action_loss: 57.19335
# update_step:   3 model loss: 49.34718, kl_loss: 3.27064, obs_loss: 44.23075, reward_loss: 1.84580, value_loss: 5.80152 action_loss: 56.23549
# update_step:   4 model loss: 48.36363, kl_loss: 3.19028, obs_loss: 43.24274, reward_loss: 1.93061, value_loss: 5.27773 action_loss: 56.26832
# update_step:   5 model loss: 47.63940, kl_loss: 3.20464, obs_loss: 42.84091, reward_loss: 1.59385, value_loss: 4.39164 action_loss: 56.77127
# update_step:   6 model loss: 48.89501, kl_loss: 3.21730, obs_loss: 44.02135, reward_loss: 1.65636, value_loss: 4.71612 action_loss: 57.54456
# update_step:   7 model loss: 49.06946, kl_loss: 3.19095, obs_loss: 43.83537, reward_loss: 2.04314, value_loss: 5.53993 action_loss: 58.08618
# update_step:   8 model loss: 47.68446, kl_loss: 3.18601, obs_loss: 43.13548, reward_loss: 1.36297, value_loss: 6.23187 action_loss: 58.44634
# update_step:   9 model loss: 49.22404, kl_loss: 3.16147, obs_loss: 44.27296, reward_loss: 1.78960, value_loss: 5.58703 action_loss: 58.46085
# update_step:  10 model loss: 47.38715, kl_loss: 3.17352, obs_loss: 42.80195, reward_loss: 1.41169, value_loss: 5.35130 action_loss: 58.69953
# update_step:  11 model loss: 48.33626, kl_loss: 3.15071, obs_loss: 43.32997, reward_loss: 1.85558, value_loss: 4.29494 action_loss: 58.59148
# update_step:  12 model loss: 48.65335, kl_loss: 3.16545, obs_loss: 43.38852, reward_loss: 2.09939, value_loss: 3.62035 action_loss: 58.44104
# update_step:  13 model loss: 48.22339, kl_loss: 3.14522, obs_loss: 43.22754, reward_loss: 1.85063, value_loss: 3.51038 action_loss: 58.34128
# update_step:  14 model loss: 48.28379, kl_loss: 3.13847, obs_loss: 43.27141, reward_loss: 1.87391, value_loss: 3.52952 action_loss: 58.60051
# update_step:  15 model loss: 49.00961, kl_loss: 3.16256, obs_loss: 43.86916, reward_loss: 1.97789, value_loss: 3.42163 action_loss: 58.97705
# update_step:  16 model loss: 49.09278, kl_loss: 3.14298, obs_loss: 44.28004, reward_loss: 1.66977, value_loss: 3.22543 action_loss: 59.35067
# update_step:  17 model loss: 47.53210, kl_loss: 3.13905, obs_loss: 42.92924, reward_loss: 1.46381, value_loss: 3.13609 action_loss: 59.75390
# update_step:  18 model loss: 48.28434, kl_loss: 3.13607, obs_loss: 43.35631, reward_loss: 1.79196, value_loss: 3.08801 action_loss: 59.99775
# update_step:  19 model loss: 48.05381, kl_loss: 3.14274, obs_loss: 43.29516, reward_loss: 1.61591, value_loss: 3.33969 action_loss: 60.54602
# update_step:  20 model loss: 47.95222, kl_loss: 3.12139, obs_loss: 43.15187, reward_loss: 1.67896, value_loss: 3.22404 action_loss: 60.79145
# update_step:  21 model loss: 48.85831, kl_loss: 3.12865, obs_loss: 43.67262, reward_loss: 2.05703, value_loss: 2.85098 action_loss: 60.55624
# update_step:  22 model loss: 47.95099, kl_loss: 3.13892, obs_loss: 43.16307, reward_loss: 1.64900, value_loss: 2.87114 action_loss: 60.40196
# update_step:  23 model loss: 48.54209, kl_loss: 3.13454, obs_loss: 43.58498, reward_loss: 1.82256, value_loss: 2.98773 action_loss: 60.18364
# update_step:  24 model loss: 48.00442, kl_loss: 3.13078, obs_loss: 43.17910, reward_loss: 1.69454, value_loss: 2.85584 action_loss: 60.28379
# update_step:  25 model loss: 48.81199, kl_loss: 3.10594, obs_loss: 43.80497, reward_loss: 1.90108, value_loss: 2.49830 action_loss: 60.49402
# update_step:  26 model loss: 47.75695, kl_loss: 3.09033, obs_loss: 43.07180, reward_loss: 1.59483, value_loss: 2.35370 action_loss: 60.53449
# update_step:  27 model loss: 48.30018, kl_loss: 3.10309, obs_loss: 43.02156, reward_loss: 2.17553, value_loss: 2.33841 action_loss: 59.93598
# update_step:  28 model loss: 48.17926, kl_loss: 3.09101, obs_loss: 43.20980, reward_loss: 1.87845, value_loss: 2.48759 action_loss: 59.30093
# update_step:  29 model loss: 47.93073, kl_loss: 3.08839, obs_loss: 43.02328, reward_loss: 1.81907, value_loss: 2.28461 action_loss: 58.97328
# update_step:  30 model loss: 47.95093, kl_loss: 3.07416, obs_loss: 43.02313, reward_loss: 1.85365, value_loss: 1.98263 action_loss: 58.83472
# update_step:  31 model loss: 47.96104, kl_loss: 3.10074, obs_loss: 43.13947, reward_loss: 1.72083, value_loss: 2.11124 action_loss: 59.02755
# update_step:  32 model loss: 48.18097, kl_loss: 3.08270, obs_loss: 43.10304, reward_loss: 1.99523, value_loss: 2.06922 action_loss: 58.74115
# update_step:  33 model loss: 47.91833, kl_loss: 3.07977, obs_loss: 43.02794, reward_loss: 1.81061, value_loss: 2.05383 action_loss: 58.58424
# update_step:  34 model loss: 47.99304, kl_loss: 3.07695, obs_loss: 43.18079, reward_loss: 1.73531, value_loss: 2.29627 action_loss: 58.79833
# update_step:  35 model loss: 47.61611, kl_loss: 3.08458, obs_loss: 42.72550, reward_loss: 1.80603, value_loss: 2.35177 action_loss: 59.00183
# update_step:  36 model loss: 47.59454, kl_loss: 3.07851, obs_loss: 42.47955, reward_loss: 2.03648, value_loss: 2.05761 action_loss: 59.07428
# update_step:  37 model loss: 47.34288, kl_loss: 3.07407, obs_loss: 42.66525, reward_loss: 1.60357, value_loss: 2.14907 action_loss: 59.58789
# update_step:  38 model loss: 48.18308, kl_loss: 3.08300, obs_loss: 43.33024, reward_loss: 1.76984, value_loss: 2.04557 action_loss: 59.98536
# update_step:  39 model loss: 47.91679, kl_loss: 3.08011, obs_loss: 43.01376, reward_loss: 1.82292, value_loss: 1.76365 action_loss: 60.27462
# update_step:  40 model loss: 48.26680, kl_loss: 3.06819, obs_loss: 43.18135, reward_loss: 2.01726, value_loss: 1.68359 action_loss: 60.70272
# update_step:  41 model loss: 48.41176, kl_loss: 3.06776, obs_loss: 43.22823, reward_loss: 2.11576, value_loss: 1.84035 action_loss: 60.57032
# update_step:  42 model loss: 48.22998, kl_loss: 3.07107, obs_loss: 43.38771, reward_loss: 1.77120, value_loss: 2.38499 action_loss: 60.44413
# update_step:  43 model loss: 48.16634, kl_loss: 3.04509, obs_loss: 43.10914, reward_loss: 2.01211, value_loss: 2.74323 action_loss: 60.39948
# update_step:  44 model loss: 47.34740, kl_loss: 3.05487, obs_loss: 42.68205, reward_loss: 1.61047, value_loss: 2.82961 action_loss: 60.31644
# update_step:  45 model loss: 48.06215, kl_loss: 3.05906, obs_loss: 42.98885, reward_loss: 2.01424, value_loss: 2.65711 action_loss: 60.17404
# update_step:  46 model loss: 48.74962, kl_loss: 3.04171, obs_loss: 43.68396, reward_loss: 2.02395, value_loss: 2.42559 action_loss: 59.89149
# update_step:  47 model loss: 46.99991, kl_loss: 3.04345, obs_loss: 42.21210, reward_loss: 1.74436, value_loss: 1.91668 action_loss: 59.73798
# update_step:  48 model loss: 46.64326, kl_loss: 3.04532, obs_loss: 42.01641, reward_loss: 1.58153, value_loss: 1.54595 action_loss: 59.47142
# update_step:  49 model loss: 47.15163, kl_loss: 3.04783, obs_loss: 42.26592, reward_loss: 1.83788, value_loss: 1.38827 action_loss: 58.93914
# update_step:  50 model loss: 47.42270, kl_loss: 3.04846, obs_loss: 42.54716, reward_loss: 1.82707, value_loss: 1.23265 action_loss: 58.51892
# update_step:  51 model loss: 47.73622, kl_loss: 3.03835, obs_loss: 43.12458, reward_loss: 1.57328, value_loss: 1.27397 action_loss: 58.25670
# update_step:  52 model loss: 48.37500, kl_loss: 3.04558, obs_loss: 43.54202, reward_loss: 1.78741, value_loss: 1.77293 action_loss: 58.37499
# update_step:  53 model loss: 48.78357, kl_loss: 3.03910, obs_loss: 43.83319, reward_loss: 1.91127, value_loss: 2.12863 action_loss: 58.30619
# update_step:  54 model loss: 48.59613, kl_loss: 3.03900, obs_loss: 43.86597, reward_loss: 1.69116, value_loss: 2.03654 action_loss: 58.17518
# update_step:  55 model loss: 47.71592, kl_loss: 3.03254, obs_loss: 42.96650, reward_loss: 1.71688, value_loss: 1.58888 action_loss: 57.91819
# update_step:  56 model loss: 48.19701, kl_loss: 3.03273, obs_loss: 43.05749, reward_loss: 2.10679, value_loss: 1.19344 action_loss: 57.67579
# update_step:  57 model loss: 48.41737, kl_loss: 3.03373, obs_loss: 43.66856, reward_loss: 1.71507, value_loss: 1.09694 action_loss: 57.63631
# update_step:  58 model loss: 47.34125, kl_loss: 3.02385, obs_loss: 42.40726, reward_loss: 1.91014, value_loss: 1.07664 action_loss: 57.68326
# update_step:  59 model loss: 47.08984, kl_loss: 3.03775, obs_loss: 42.27853, reward_loss: 1.77356, value_loss: 1.06337 action_loss: 58.07589
# update_step:  60 model loss: 47.78851, kl_loss: 3.02551, obs_loss: 42.99434, reward_loss: 1.76865, value_loss: 1.19271 action_loss: 58.62489
# update_step:  61 model loss: 47.82576, kl_loss: 3.02740, obs_loss: 42.92963, reward_loss: 1.86873, value_loss: 1.58713 action_loss: 59.38523
# update_step:  62 model loss: 47.03294, kl_loss: 3.02013, obs_loss: 42.46312, reward_loss: 1.54969, value_loss: 2.14227 action_loss: 60.20991
# update_step:  63 model loss: 46.81922, kl_loss: 3.02751, obs_loss: 42.18658, reward_loss: 1.60513, value_loss: 2.24947 action_loss: 60.82521
# update_step:  64 model loss: 47.72540, kl_loss: 3.01776, obs_loss: 43.03367, reward_loss: 1.67397, value_loss: 1.50432 action_loss: 60.89419
# update_step:  65 model loss: 46.98355, kl_loss: 3.02913, obs_loss: 42.19297, reward_loss: 1.76145, value_loss: 1.23335 action_loss: 60.54633
# update_step:  66 model loss: 47.29427, kl_loss: 3.02145, obs_loss: 42.68929, reward_loss: 1.58352, value_loss: 2.52168 action_loss: 59.97019
# update_step:  67 model loss: 47.68583, kl_loss: 3.02003, obs_loss: 42.74305, reward_loss: 1.92275, value_loss: 4.05158 action_loss: 59.65744
# update_step:  68 model loss: 46.65490, kl_loss: 3.02633, obs_loss: 41.78863, reward_loss: 1.83995, value_loss: 3.67404 action_loss: 59.92387
# update_step:  69 model loss: 46.94265, kl_loss: 3.01678, obs_loss: 42.30623, reward_loss: 1.61963, value_loss: 3.03054 action_loss: 60.12114
# update_step:  70 model loss: 46.71569, kl_loss: 3.01452, obs_loss: 42.05356, reward_loss: 1.64762, value_loss: 2.04036 action_loss: 60.43092
# update_step:  71 model loss: 47.33904, kl_loss: 3.02212, obs_loss: 42.38612, reward_loss: 1.93079, value_loss: 1.25881 action_loss: 60.71837
# update_step:  72 model loss: 47.70057, kl_loss: 3.01155, obs_loss: 42.83318, reward_loss: 1.85583, value_loss: 1.07547 action_loss: 60.75216
# update_step:  73 model loss: 48.09875, kl_loss: 3.01078, obs_loss: 43.15057, reward_loss: 1.93740, value_loss: 1.05497 action_loss: 60.38593
# update_step:  74 model loss: 47.50289, kl_loss: 3.01330, obs_loss: 42.89499, reward_loss: 1.59460, value_loss: 1.09363 action_loss: 60.21983
# update_step:  75 model loss: 46.24152, kl_loss: 3.01740, obs_loss: 41.61005, reward_loss: 1.61406, value_loss: 1.12482 action_loss: 60.01722
# update_step:  76 model loss: 47.17249, kl_loss: 3.01840, obs_loss: 42.27927, reward_loss: 1.87482, value_loss: 1.07845 action_loss: 59.79671
# update_step:  77 model loss: 47.39722, kl_loss: 3.01600, obs_loss: 42.72465, reward_loss: 1.65657, value_loss: 0.99035 action_loss: 59.24784
# update_step:  78 model loss: 46.36203, kl_loss: 3.01486, obs_loss: 41.91494, reward_loss: 1.43223, value_loss: 1.18198 action_loss: 58.58981
# update_step:  79 model loss: 46.89097, kl_loss: 3.01414, obs_loss: 42.19884, reward_loss: 1.67798, value_loss: 1.37331 action_loss: 58.11998
# update_step:  80 model loss: 47.40006, kl_loss: 3.01572, obs_loss: 42.76782, reward_loss: 1.61652, value_loss: 1.10224 action_loss: 58.03404
# update_step:  81 model loss: 46.76828, kl_loss: 3.00944, obs_loss: 42.05271, reward_loss: 1.70613, value_loss: 0.91622 action_loss: 58.13356
# update_step:  82 model loss: 46.42973, kl_loss: 3.01627, obs_loss: 41.77105, reward_loss: 1.64241, value_loss: 1.20612 action_loss: 58.39759
# update_step:  83 model loss: 46.89873, kl_loss: 3.02218, obs_loss: 42.06917, reward_loss: 1.80738, value_loss: 1.67741 action_loss: 58.58083
# update_step:  84 model loss: 48.25497, kl_loss: 3.01094, obs_loss: 42.90577, reward_loss: 2.33826, value_loss: 1.20560 action_loss: 58.11342
# update_step:  85 model loss: 48.94771, kl_loss: 3.00852, obs_loss: 43.79121, reward_loss: 2.14798, value_loss: 0.90065 action_loss: 57.71737
# update_step:  86 model loss: 47.42181, kl_loss: 3.01375, obs_loss: 42.70427, reward_loss: 1.70379, value_loss: 0.94962 action_loss: 57.25530
# update_step:  87 model loss: 47.41152, kl_loss: 3.01281, obs_loss: 42.17249, reward_loss: 2.22622, value_loss: 1.25019 action_loss: 56.86619
# update_step:  88 model loss: 46.91196, kl_loss: 3.01044, obs_loss: 42.39670, reward_loss: 1.50482, value_loss: 1.33592 action_loss: 56.64140
# update_step:  89 model loss: 47.37487, kl_loss: 3.01055, obs_loss: 42.45586, reward_loss: 1.90846, value_loss: 0.86936 action_loss: 57.01146
# update_step:  90 model loss: 46.09322, kl_loss: 3.01358, obs_loss: 41.48328, reward_loss: 1.59635, value_loss: 1.01077 action_loss: 57.45913
# update_step:  91 model loss: 46.83362, kl_loss: 3.00782, obs_loss: 42.28040, reward_loss: 1.54540, value_loss: 1.24986 action_loss: 57.59745
# update_step:  92 model loss: 47.16548, kl_loss: 3.00681, obs_loss: 42.41658, reward_loss: 1.74209, value_loss: 1.47374 action_loss: 57.78778
# update_step:  93 model loss: 47.72170, kl_loss: 3.00467, obs_loss: 42.82984, reward_loss: 1.88719, value_loss: 1.73601 action_loss: 58.13659
# update_step:  94 model loss: 46.64049, kl_loss: 3.00631, obs_loss: 42.15478, reward_loss: 1.47941, value_loss: 2.27144 action_loss: 58.77776
# update_step:  95 model loss: 46.98181, kl_loss: 3.00704, obs_loss: 42.40467, reward_loss: 1.57010, value_loss: 2.32008 action_loss: 59.27309
# update_step:  96 model loss: 47.21551, kl_loss: 3.00987, obs_loss: 42.26690, reward_loss: 1.93874, value_loss: 1.43858 action_loss: 59.30570
# update_step:  97 model loss: 47.59756, kl_loss: 3.00720, obs_loss: 42.52615, reward_loss: 2.06422, value_loss: 0.86983 action_loss: 59.16767
# update_step:  98 model loss: 46.92202, kl_loss: 3.01047, obs_loss: 42.16381, reward_loss: 1.74774, value_loss: 1.20985 action_loss: 59.00077
# update_step:  99 model loss: 46.59437, kl_loss: 3.00788, obs_loss: 42.19305, reward_loss: 1.39344, value_loss: 1.74451 action_loss: 58.99132
# update_step: 100 model loss: 47.50136, kl_loss: 3.00508, obs_loss: 42.61839, reward_loss: 1.87788, value_loss: 2.13331 action_loss: 58.91396
# elasped time for update: 20.97s
# episode [  13/ 200] is collected. Total reward is -306.263247
# elasped time for interaction: 1.82s
# update_step:   1 model loss: 50.52655, kl_loss: 3.03176, obs_loss: 45.55061, reward_loss: 1.94418, value_loss: 2.20918 action_loss: 58.81339
# update_step:   2 model loss: 49.30257, kl_loss: 3.01969, obs_loss: 44.55880, reward_loss: 1.72408, value_loss: 2.28447 action_loss: 58.54464
# update_step:   3 model loss: 49.21527, kl_loss: 3.02622, obs_loss: 44.32668, reward_loss: 1.86237, value_loss: 2.13202 action_loss: 58.17514
# update_step:   4 model loss: 48.07278, kl_loss: 3.02154, obs_loss: 43.28226, reward_loss: 1.76898, value_loss: 1.43888 action_loss: 58.15771
# update_step:   5 model loss: 49.41934, kl_loss: 3.01558, obs_loss: 44.51837, reward_loss: 1.88539, value_loss: 1.31834 action_loss: 57.56833
# update_step:   6 model loss: 49.79908, kl_loss: 3.02165, obs_loss: 44.99970, reward_loss: 1.77773, value_loss: 1.25034 action_loss: 56.83120
# update_step:   7 model loss: 49.02874, kl_loss: 3.02495, obs_loss: 44.20048, reward_loss: 1.80330, value_loss: 1.34393 action_loss: 55.79721
# update_step:   8 model loss: 47.89189, kl_loss: 3.01777, obs_loss: 43.26592, reward_loss: 1.60820, value_loss: 0.98127 action_loss: 55.16467
# update_step:   9 model loss: 49.72517, kl_loss: 3.03328, obs_loss: 44.87085, reward_loss: 1.82104, value_loss: 0.89431 action_loss: 54.29096
# update_step:  10 model loss: 47.96856, kl_loss: 3.00887, obs_loss: 43.12760, reward_loss: 1.83209, value_loss: 0.83711 action_loss: 54.01450
# update_step:  11 model loss: 47.15765, kl_loss: 3.01282, obs_loss: 42.50650, reward_loss: 1.63833, value_loss: 1.68478 action_loss: 54.20539
# update_step:  12 model loss: 49.08764, kl_loss: 3.01530, obs_loss: 44.34874, reward_loss: 1.72360, value_loss: 2.58791 action_loss: 54.07114
# update_step:  13 model loss: 48.60933, kl_loss: 3.00947, obs_loss: 43.66376, reward_loss: 1.93610, value_loss: 3.42680 action_loss: 54.06273
# update_step:  14 model loss: 48.35571, kl_loss: 3.02321, obs_loss: 43.60438, reward_loss: 1.72812, value_loss: 3.12474 action_loss: 53.69853
# update_step:  15 model loss: 47.36655, kl_loss: 3.01602, obs_loss: 42.53930, reward_loss: 1.81124, value_loss: 1.55992 action_loss: 52.86563
# update_step:  16 model loss: 48.00636, kl_loss: 3.02421, obs_loss: 43.28662, reward_loss: 1.69552, value_loss: 0.88726 action_loss: 52.29197
# update_step:  17 model loss: 48.63514, kl_loss: 3.02112, obs_loss: 43.88984, reward_loss: 1.72419, value_loss: 1.25579 action_loss: 51.09052
# update_step:  18 model loss: 47.54619, kl_loss: 3.01887, obs_loss: 42.83580, reward_loss: 1.69152, value_loss: 1.20321 action_loss: 51.16337
# update_step:  19 model loss: 46.95195, kl_loss: 3.00968, obs_loss: 42.04658, reward_loss: 1.89569, value_loss: 0.82940 action_loss: 51.64962
# update_step:  20 model loss: 47.27780, kl_loss: 3.01061, obs_loss: 42.32110, reward_loss: 1.94609, value_loss: 0.98433 action_loss: 51.14223
# update_step:  21 model loss: 46.60896, kl_loss: 3.01867, obs_loss: 41.71147, reward_loss: 1.87882, value_loss: 3.90931 action_loss: 49.12411
# update_step:  22 model loss: 46.54858, kl_loss: 3.01839, obs_loss: 41.85455, reward_loss: 1.67564, value_loss: 8.10747 action_loss: 47.46331
# update_step:  23 model loss: 45.92274, kl_loss: 3.02355, obs_loss: 41.43607, reward_loss: 1.46312, value_loss: 11.70170 action_loss: 46.18280
# update_step:  24 model loss: 46.46520, kl_loss: 3.02048, obs_loss: 41.78359, reward_loss: 1.66114, value_loss: 9.77937 action_loss: 45.87781
# update_step:  25 model loss: 45.36236, kl_loss: 3.01366, obs_loss: 40.84882, reward_loss: 1.49988, value_loss: 13.33327 action_loss: 44.44217
# update_step:  26 model loss: 46.25041, kl_loss: 3.01082, obs_loss: 41.54518, reward_loss: 1.69441, value_loss: 6.74552 action_loss: 45.11570
# update_step:  27 model loss: 46.07019, kl_loss: 3.01089, obs_loss: 41.43512, reward_loss: 1.62417, value_loss: 6.01833 action_loss: 44.47656
# update_step:  28 model loss: 45.52149, kl_loss: 3.01008, obs_loss: 40.90320, reward_loss: 1.60822, value_loss: 12.66522 action_loss: 42.04948
# update_step:  29 model loss: 46.19479, kl_loss: 3.03035, obs_loss: 41.64928, reward_loss: 1.51516, value_loss: 7.98997 action_loss: 42.06362
# update_step:  30 model loss: 45.61773, kl_loss: 3.00798, obs_loss: 40.85310, reward_loss: 1.75665, value_loss: 2.29697 action_loss: 42.94256
# update_step:  31 model loss: 45.66850, kl_loss: 3.01013, obs_loss: 41.19727, reward_loss: 1.46110, value_loss: 0.57538 action_loss: 43.56047
# update_step:  32 model loss: 45.51708, kl_loss: 3.01556, obs_loss: 40.72600, reward_loss: 1.77552, value_loss: 1.99940 action_loss: 44.12137
# update_step:  33 model loss: 45.03726, kl_loss: 3.01991, obs_loss: 40.36322, reward_loss: 1.65412, value_loss: 5.40740 action_loss: 44.76804
# update_step:  34 model loss: 45.44540, kl_loss: 3.01055, obs_loss: 40.54865, reward_loss: 1.88620, value_loss: 6.44529 action_loss: 44.62637
# update_step:  35 model loss: 45.04778, kl_loss: 3.01298, obs_loss: 40.48191, reward_loss: 1.55289, value_loss: 3.89710 action_loss: 43.58646
# update_step:  36 model loss: 45.14333, kl_loss: 3.01836, obs_loss: 40.35593, reward_loss: 1.76904, value_loss: 2.38145 action_loss: 42.82891
# update_step:  37 model loss: 44.62140, kl_loss: 3.01863, obs_loss: 40.09213, reward_loss: 1.51063, value_loss: 1.83255 action_loss: 42.64156
# update_step:  38 model loss: 44.25896, kl_loss: 3.01147, obs_loss: 39.75462, reward_loss: 1.49288, value_loss: 2.00889 action_loss: 42.96653
# update_step:  39 model loss: 44.47915, kl_loss: 3.00866, obs_loss: 40.01727, reward_loss: 1.45322, value_loss: 1.87639 action_loss: 43.26723
# update_step:  40 model loss: 44.33123, kl_loss: 3.02013, obs_loss: 39.81129, reward_loss: 1.49982, value_loss: 1.85292 action_loss: 43.69868
# update_step:  41 model loss: 44.43502, kl_loss: 3.01494, obs_loss: 39.77826, reward_loss: 1.64182, value_loss: 1.04750 action_loss: 43.72857
# update_step:  42 model loss: 44.17294, kl_loss: 3.00999, obs_loss: 39.86352, reward_loss: 1.29943, value_loss: 1.29774 action_loss: 44.59154
# update_step:  43 model loss: 44.52756, kl_loss: 3.01284, obs_loss: 39.72739, reward_loss: 1.78733, value_loss: 1.55402 action_loss: 45.45794
# update_step:  44 model loss: 43.61187, kl_loss: 3.02336, obs_loss: 39.21628, reward_loss: 1.37223, value_loss: 0.71687 action_loss: 45.39159
# update_step:  45 model loss: 43.44139, kl_loss: 3.01601, obs_loss: 38.72236, reward_loss: 1.70302, value_loss: 1.49686 action_loss: 44.32728
# update_step:  46 model loss: 43.91217, kl_loss: 3.01638, obs_loss: 39.60390, reward_loss: 1.29189, value_loss: 3.67469 action_loss: 43.88178
# update_step:  47 model loss: 44.63774, kl_loss: 3.03465, obs_loss: 39.92225, reward_loss: 1.68085, value_loss: 7.20084 action_loss: 43.16131
# update_step:  48 model loss: 43.80646, kl_loss: 3.01396, obs_loss: 39.01225, reward_loss: 1.78025, value_loss: 6.60487 action_loss: 43.49675
# update_step:  49 model loss: 43.05190, kl_loss: 3.00964, obs_loss: 38.64261, reward_loss: 1.39965, value_loss: 3.89028 action_loss: 44.28523
# update_step:  50 model loss: 43.62391, kl_loss: 3.02178, obs_loss: 39.27707, reward_loss: 1.32507, value_loss: 1.24007 action_loss: 45.45331
# update_step:  51 model loss: 43.67419, kl_loss: 3.01484, obs_loss: 38.75104, reward_loss: 1.90831, value_loss: 1.11163 action_loss: 45.28765
# update_step:  52 model loss: 43.29804, kl_loss: 3.02623, obs_loss: 38.51788, reward_loss: 1.75394, value_loss: 1.90225 action_loss: 44.23578
# update_step:  53 model loss: 43.64512, kl_loss: 3.03668, obs_loss: 39.04852, reward_loss: 1.55992, value_loss: 3.90393 action_loss: 42.91139
# update_step:  54 model loss: 43.65427, kl_loss: 3.01211, obs_loss: 38.79850, reward_loss: 1.84366, value_loss: 3.64826 action_loss: 42.36953
# update_step:  55 model loss: 42.91079, kl_loss: 3.02764, obs_loss: 38.21561, reward_loss: 1.66754, value_loss: 1.78492 action_loss: 42.41306
# update_step:  56 model loss: 43.86571, kl_loss: 3.02320, obs_loss: 38.87885, reward_loss: 1.96367, value_loss: 0.48635 action_loss: 43.09397
# update_step:  57 model loss: 43.19277, kl_loss: 3.02064, obs_loss: 38.47643, reward_loss: 1.69571, value_loss: 0.75051 action_loss: 43.18734
# update_step:  58 model loss: 42.76646, kl_loss: 3.02065, obs_loss: 37.98752, reward_loss: 1.75830, value_loss: 2.32654 action_loss: 43.69695
# update_step:  59 model loss: 42.61056, kl_loss: 3.02058, obs_loss: 37.99744, reward_loss: 1.59254, value_loss: 2.68814 action_loss: 43.53046
# update_step:  60 model loss: 42.49106, kl_loss: 3.02471, obs_loss: 37.89150, reward_loss: 1.57486, value_loss: 1.85122 action_loss: 42.98510
# update_step:  61 model loss: 42.14396, kl_loss: 3.02471, obs_loss: 37.59695, reward_loss: 1.52230, value_loss: 1.10846 action_loss: 42.46425
# update_step:  62 model loss: 42.20670, kl_loss: 3.05069, obs_loss: 37.53671, reward_loss: 1.61929, value_loss: 0.77617 action_loss: 42.16612
# update_step:  63 model loss: 42.77000, kl_loss: 3.02038, obs_loss: 37.88316, reward_loss: 1.86646, value_loss: 0.44057 action_loss: 41.77888
# update_step:  64 model loss: 41.32445, kl_loss: 3.01809, obs_loss: 36.80746, reward_loss: 1.49890, value_loss: 0.42456 action_loss: 41.63237
# update_step:  65 model loss: 42.95674, kl_loss: 3.02593, obs_loss: 37.98608, reward_loss: 1.94472, value_loss: 0.47376 action_loss: 42.18089
# update_step:  66 model loss: 41.91486, kl_loss: 3.01980, obs_loss: 37.47186, reward_loss: 1.42320, value_loss: 1.33577 action_loss: 43.29206
# update_step:  67 model loss: 41.62122, kl_loss: 3.02310, obs_loss: 36.77567, reward_loss: 1.82246, value_loss: 1.88343 action_loss: 43.83470
# update_step:  68 model loss: 42.11802, kl_loss: 3.02753, obs_loss: 37.50279, reward_loss: 1.58770, value_loss: 2.56026 action_loss: 44.63171
# update_step:  69 model loss: 42.44196, kl_loss: 3.02105, obs_loss: 37.80743, reward_loss: 1.61349, value_loss: 2.96921 action_loss: 45.30980
# update_step:  70 model loss: 42.46377, kl_loss: 3.03307, obs_loss: 37.30274, reward_loss: 2.12796, value_loss: 0.67268 action_loss: 44.32005
# update_step:  71 model loss: 43.09329, kl_loss: 3.04826, obs_loss: 38.13304, reward_loss: 1.91199, value_loss: 0.91658 action_loss: 43.42237
# update_step:  72 model loss: 42.26219, kl_loss: 3.02587, obs_loss: 37.54041, reward_loss: 1.69591, value_loss: 3.03633 action_loss: 42.61375
# update_step:  73 model loss: 41.94921, kl_loss: 3.02567, obs_loss: 37.28532, reward_loss: 1.63822, value_loss: 10.95912 action_loss: 40.63226
# update_step:  74 model loss: 42.37480, kl_loss: 3.03406, obs_loss: 37.77974, reward_loss: 1.56099, value_loss: 11.36639 action_loss: 40.56574
# update_step:  75 model loss: 41.64230, kl_loss: 3.02670, obs_loss: 36.94349, reward_loss: 1.67211, value_loss: 5.53709 action_loss: 41.88927
# update_step:  76 model loss: 42.59480, kl_loss: 3.02177, obs_loss: 38.09383, reward_loss: 1.47920, value_loss: 0.96363 action_loss: 43.58815
# update_step:  77 model loss: 42.23562, kl_loss: 3.04345, obs_loss: 37.41251, reward_loss: 1.77966, value_loss: 1.09713 action_loss: 45.14074
# update_step:  78 model loss: 41.95771, kl_loss: 3.03820, obs_loss: 36.99254, reward_loss: 1.92698, value_loss: 1.30685 action_loss: 45.08671
# update_step:  79 model loss: 41.84266, kl_loss: 3.02690, obs_loss: 37.06965, reward_loss: 1.74611, value_loss: 0.46731 action_loss: 43.90232
# update_step:  80 model loss: 40.99812, kl_loss: 3.02661, obs_loss: 36.64896, reward_loss: 1.32255, value_loss: 1.98226 action_loss: 42.17849
# update_step:  81 model loss: 41.96731, kl_loss: 3.06880, obs_loss: 37.10345, reward_loss: 1.79505, value_loss: 2.86862 action_loss: 41.50518
# update_step:  82 model loss: 41.05941, kl_loss: 3.03045, obs_loss: 36.31034, reward_loss: 1.71863, value_loss: 2.06256 action_loss: 41.61719
# update_step:  83 model loss: 41.46972, kl_loss: 3.04560, obs_loss: 37.04115, reward_loss: 1.38297, value_loss: 0.48970 action_loss: 42.57306
# update_step:  84 model loss: 41.31005, kl_loss: 3.02007, obs_loss: 36.67370, reward_loss: 1.61629, value_loss: 1.52865 action_loss: 43.85057
# update_step:  85 model loss: 41.73293, kl_loss: 3.02491, obs_loss: 36.86603, reward_loss: 1.84200, value_loss: 2.84269 action_loss: 44.30375
# update_step:  86 model loss: 41.11554, kl_loss: 3.02986, obs_loss: 36.52861, reward_loss: 1.55707, value_loss: 2.85998 action_loss: 44.25636
# update_step:  87 model loss: 41.66137, kl_loss: 3.01746, obs_loss: 37.16265, reward_loss: 1.48126, value_loss: 1.80334 action_loss: 43.93106
# update_step:  88 model loss: 40.89261, kl_loss: 3.02060, obs_loss: 36.40665, reward_loss: 1.46536, value_loss: 1.53703 action_loss: 43.87732
# update_step:  89 model loss: 40.69084, kl_loss: 3.01637, obs_loss: 36.20926, reward_loss: 1.46521, value_loss: 0.56037 action_loss: 43.25397
# update_step:  90 model loss: 41.32100, kl_loss: 3.01790, obs_loss: 36.37420, reward_loss: 1.92889, value_loss: 0.90305 action_loss: 42.30620
# update_step:  91 model loss: 40.82186, kl_loss: 3.01845, obs_loss: 36.29718, reward_loss: 1.50623, value_loss: 2.09919 action_loss: 41.65973
# update_step:  92 model loss: 40.90502, kl_loss: 3.02578, obs_loss: 36.13586, reward_loss: 1.74338, value_loss: 2.58812 action_loss: 41.43302
# update_step:  93 model loss: 41.18271, kl_loss: 3.02006, obs_loss: 36.29079, reward_loss: 1.87187, value_loss: 1.66230 action_loss: 41.83401
# update_step:  94 model loss: 40.99903, kl_loss: 3.01752, obs_loss: 36.40940, reward_loss: 1.57211, value_loss: 0.54431 action_loss: 42.68761
# update_step:  95 model loss: 40.98707, kl_loss: 3.01981, obs_loss: 36.40946, reward_loss: 1.55780, value_loss: 0.47138 action_loss: 42.83645
# update_step:  96 model loss: 40.87315, kl_loss: 3.02188, obs_loss: 35.88551, reward_loss: 1.96577, value_loss: 0.95818 action_loss: 41.54348
# update_step:  97 model loss: 40.67010, kl_loss: 3.02206, obs_loss: 35.90586, reward_loss: 1.74219, value_loss: 2.36204 action_loss: 40.37480
# update_step:  98 model loss: 40.86830, kl_loss: 3.01489, obs_loss: 36.17293, reward_loss: 1.68048, value_loss: 5.19860 action_loss: 38.87482
# update_step:  99 model loss: 40.49620, kl_loss: 3.02198, obs_loss: 35.66711, reward_loss: 1.80711, value_loss: 3.70459 action_loss: 38.78787
# update_step: 100 model loss: 40.44570, kl_loss: 3.02046, obs_loss: 35.94648, reward_loss: 1.47876, value_loss: 1.93111 action_loss: 38.99301
# elasped time for update: 20.82s
# episode [  14/ 200] is collected. Total reward is -269.623652
# elasped time for interaction: 1.79s
# update_step:   1 model loss: 40.49908, kl_loss: 3.02700, obs_loss: 35.97274, reward_loss: 1.49934, value_loss: 0.46838 action_loss: 39.56831
# update_step:   2 model loss: 40.98097, kl_loss: 3.03797, obs_loss: 36.08591, reward_loss: 1.85708, value_loss: 1.99491 action_loss: 40.95854
# update_step:   3 model loss: 40.41451, kl_loss: 3.01632, obs_loss: 35.82027, reward_loss: 1.57792, value_loss: 7.95499 action_loss: 42.54245
# update_step:   4 model loss: 40.67873, kl_loss: 3.02405, obs_loss: 36.09000, reward_loss: 1.56468, value_loss: 15.78801 action_loss: 43.86858
# update_step:   5 model loss: 41.30129, kl_loss: 3.01263, obs_loss: 36.60892, reward_loss: 1.67974, value_loss: 22.52038 action_loss: 44.94126
# update_step:   6 model loss: 40.56161, kl_loss: 3.03380, obs_loss: 35.97648, reward_loss: 1.55134, value_loss: 25.09583 action_loss: 45.31290
# update_step:   7 model loss: 40.24637, kl_loss: 3.02760, obs_loss: 35.85364, reward_loss: 1.36513, value_loss: 24.65905 action_loss: 45.43758
# update_step:   8 model loss: 40.54308, kl_loss: 3.02313, obs_loss: 35.79504, reward_loss: 1.72490, value_loss: 19.76087 action_loss: 45.03101
# update_step:   9 model loss: 39.80399, kl_loss: 3.02355, obs_loss: 35.43891, reward_loss: 1.34153, value_loss: 13.83357 action_loss: 44.54268
# update_step:  10 model loss: 40.77332, kl_loss: 3.02235, obs_loss: 36.17438, reward_loss: 1.57659, value_loss: 9.69097 action_loss: 44.24777
# update_step:  11 model loss: 40.23454, kl_loss: 3.01553, obs_loss: 35.58945, reward_loss: 1.62956, value_loss: 5.62366 action_loss: 43.76981
# update_step:  12 model loss: 40.40278, kl_loss: 3.02084, obs_loss: 35.77889, reward_loss: 1.60305, value_loss: 3.66307 action_loss: 43.86375
# update_step:  13 model loss: 40.37511, kl_loss: 3.01905, obs_loss: 35.63079, reward_loss: 1.72527, value_loss: 3.41750 action_loss: 44.54939
# update_step:  14 model loss: 40.65244, kl_loss: 3.03266, obs_loss: 35.97063, reward_loss: 1.64914, value_loss: 4.88622 action_loss: 45.86544
# update_step:  15 model loss: 40.39964, kl_loss: 3.03708, obs_loss: 35.68086, reward_loss: 1.68170, value_loss: 6.81336 action_loss: 47.23100
# update_step:  16 model loss: 40.62165, kl_loss: 3.02297, obs_loss: 36.34330, reward_loss: 1.25537, value_loss: 8.40056 action_loss: 48.63485
# update_step:  17 model loss: 40.99313, kl_loss: 3.04261, obs_loss: 35.98813, reward_loss: 1.96239, value_loss: 7.56997 action_loss: 49.44220
# update_step:  18 model loss: 39.65523, kl_loss: 3.04209, obs_loss: 35.31343, reward_loss: 1.29971, value_loss: 5.49552 action_loss: 49.84058
# update_step:  19 model loss: 39.99477, kl_loss: 3.03025, obs_loss: 35.61211, reward_loss: 1.35241, value_loss: 2.51269 action_loss: 49.83948
# update_step:  20 model loss: 40.39719, kl_loss: 3.01315, obs_loss: 35.58983, reward_loss: 1.79421, value_loss: 0.65742 action_loss: 49.29892
# update_step:  21 model loss: 40.19435, kl_loss: 3.01236, obs_loss: 35.73147, reward_loss: 1.45051, value_loss: 2.14141 action_loss: 48.64704
# update_step:  22 model loss: 40.72338, kl_loss: 3.01692, obs_loss: 36.19759, reward_loss: 1.50887, value_loss: 5.58274 action_loss: 48.14559
# update_step:  23 model loss: 40.57550, kl_loss: 3.04236, obs_loss: 36.04900, reward_loss: 1.48414, value_loss: 7.05446 action_loss: 48.28048
# update_step:  24 model loss: 39.95047, kl_loss: 3.01897, obs_loss: 35.42856, reward_loss: 1.50294, value_loss: 6.53117 action_loss: 48.80376
# update_step:  25 model loss: 39.95533, kl_loss: 3.02369, obs_loss: 35.39559, reward_loss: 1.53605, value_loss: 3.51910 action_loss: 49.93961
# update_step:  26 model loss: 39.69691, kl_loss: 3.03226, obs_loss: 35.16493, reward_loss: 1.49972, value_loss: 1.32851 action_loss: 51.18383
# update_step:  27 model loss: 39.87657, kl_loss: 3.02520, obs_loss: 35.51411, reward_loss: 1.33725, value_loss: 0.83168 action_loss: 51.55328
# update_step:  28 model loss: 39.54576, kl_loss: 3.03026, obs_loss: 35.28445, reward_loss: 1.23105, value_loss: 0.73592 action_loss: 51.59809
# update_step:  29 model loss: 40.19158, kl_loss: 3.03478, obs_loss: 35.60783, reward_loss: 1.54896, value_loss: 0.88639 action_loss: 51.05402
# update_step:  30 model loss: 39.68469, kl_loss: 3.03065, obs_loss: 35.23473, reward_loss: 1.41931, value_loss: 1.24582 action_loss: 50.33184
# update_step:  31 model loss: 40.19938, kl_loss: 3.04554, obs_loss: 35.61850, reward_loss: 1.53534, value_loss: 2.37296 action_loss: 49.12963
# update_step:  32 model loss: 39.64678, kl_loss: 3.07525, obs_loss: 35.23494, reward_loss: 1.33659, value_loss: 2.95727 action_loss: 48.35231
# update_step:  33 model loss: 39.98016, kl_loss: 3.02004, obs_loss: 35.24574, reward_loss: 1.71438, value_loss: 2.32070 action_loss: 48.06325
# update_step:  34 model loss: 39.56121, kl_loss: 3.01781, obs_loss: 35.25208, reward_loss: 1.29132, value_loss: 1.03528 action_loss: 48.18586
# update_step:  35 model loss: 38.96466, kl_loss: 3.02396, obs_loss: 34.80594, reward_loss: 1.13477, value_loss: 0.74518 action_loss: 48.73592
# ...
# update_step:   1 model loss: 19.30688, kl_loss: 3.03078, obs_loss: 16.20298, reward_loss: 0.07312, value_loss: 1.01748 action_loss: 0.11648
# update_step:   2 model loss: 19.94234, kl_loss: 3.04881, obs_loss: 16.83768, reward_loss: 0.05586, value_loss: 0.92212 action_loss: -0.49617
# update_step:   3 model loss: 19.16842, kl_loss: 3.04229, obs_loss: 16.07199, reward_loss: 0.05414, value_loss: 0.90098 action_loss: -0.70334
# update_step:   4 model loss: 19.43797, kl_loss: 3.03156, obs_loss: 16.34526, reward_loss: 0.06116, value_loss: 0.84158 action_loss: -0.03109
# update_step:   5 model loss: 19.28103, kl_loss: 3.04588, obs_loss: 16.18258, reward_loss: 0.05258, value_loss: 1.37424 action_loss: 0.91602
# update_step:   6 model loss: 18.54564, kl_loss: 3.02099, obs_loss: 15.49852, reward_loss: 0.02612, value_loss: 1.81851 action_loss: 1.34430
# update_step:   7 model loss: 18.97085, kl_loss: 3.02363, obs_loss: 15.90842, reward_loss: 0.03880, value_loss: 1.60580 action_loss: 1.10242
# update_step:   8 model loss: 19.86125, kl_loss: 3.04243, obs_loss: 16.76466, reward_loss: 0.05416, value_loss: 0.80596 action_loss: 0.50626
# update_step:   9 model loss: 18.96362, kl_loss: 3.03982, obs_loss: 15.86876, reward_loss: 0.05504, value_loss: 1.30935 action_loss: -0.65472
# update_step:  10 model loss: 19.14671, kl_loss: 3.03495, obs_loss: 16.05758, reward_loss: 0.05418, value_loss: 1.12194 action_loss: -0.77235
# update_step:  11 model loss: 19.81206, kl_loss: 3.02863, obs_loss: 16.72155, reward_loss: 0.06187, value_loss: 0.68384 action_loss: 0.47538
# update_step:  12 model loss: 19.18450, kl_loss: 3.02409, obs_loss: 16.12833, reward_loss: 0.03209, value_loss: 1.08790 action_loss: 1.22287
# update_step:  13 model loss: 18.73088, kl_loss: 3.02293, obs_loss: 15.67481, reward_loss: 0.03314, value_loss: 0.83315 action_loss: 0.81773
# update_step:  14 model loss: 19.17710, kl_loss: 3.03282, obs_loss: 16.08438, reward_loss: 0.05989, value_loss: 0.90804 action_loss: 1.11087
# update_step:  15 model loss: 19.37526, kl_loss: 3.04301, obs_loss: 16.29093, reward_loss: 0.04132, value_loss: 1.07468 action_loss: 1.43017
# update_step:  16 model loss: 19.01202, kl_loss: 3.02497, obs_loss: 15.94080, reward_loss: 0.04625, value_loss: 0.62677 action_loss: 1.09442
# update_step:  17 model loss: 20.19504, kl_loss: 3.04113, obs_loss: 17.09140, reward_loss: 0.06251, value_loss: 0.62396 action_loss: 0.89731
# update_step:  18 model loss: 18.64189, kl_loss: 3.01953, obs_loss: 15.57666, reward_loss: 0.04570, value_loss: 0.85579 action_loss: 1.52016
# update_step:  19 model loss: 18.85699, kl_loss: 3.02646, obs_loss: 15.78096, reward_loss: 0.04958, value_loss: 0.74143 action_loss: 1.05182
# update_step:  20 model loss: 19.71336, kl_loss: 3.02778, obs_loss: 16.63866, reward_loss: 0.04692, value_loss: 0.96060 action_loss: 0.15611
# update_step:  21 model loss: 18.90500, kl_loss: 3.02326, obs_loss: 15.84222, reward_loss: 0.03952, value_loss: 0.90900 action_loss: 0.16743
# update_step:  22 model loss: 19.77666, kl_loss: 3.02673, obs_loss: 16.71779, reward_loss: 0.03214, value_loss: 0.75800 action_loss: 0.61708
# update_step:  23 model loss: 19.30876, kl_loss: 3.02502, obs_loss: 16.23821, reward_loss: 0.04553, value_loss: 0.69911 action_loss: 0.47623
# update_step:  24 model loss: 19.34672, kl_loss: 3.04070, obs_loss: 16.27050, reward_loss: 0.03552, value_loss: 0.77383 action_loss: 0.13057
# update_step:  25 model loss: 18.59111, kl_loss: 3.02405, obs_loss: 15.52888, reward_loss: 0.03817, value_loss: 0.62528 action_loss: 0.59811
# update_step:  26 model loss: 18.90961, kl_loss: 3.02157, obs_loss: 15.85441, reward_loss: 0.03362, value_loss: 0.75983 action_loss: 1.30562
# update_step:  27 model loss: 19.79502, kl_loss: 3.02680, obs_loss: 16.72923, reward_loss: 0.03899, value_loss: 1.33666 action_loss: 2.21459
# update_step:  28 model loss: 19.20316, kl_loss: 3.02958, obs_loss: 16.13429, reward_loss: 0.03928, value_loss: 0.63441 action_loss: 1.16215
# update_step:  29 model loss: 19.23104, kl_loss: 3.04243, obs_loss: 16.14626, reward_loss: 0.04235, value_loss: 0.60526 action_loss: 1.12198
# update_step:  30 model loss: 19.19166, kl_loss: 3.04774, obs_loss: 16.10503, reward_loss: 0.03890, value_loss: 0.91865 action_loss: 1.66682
# update_step:  31 model loss: 18.80077, kl_loss: 3.03015, obs_loss: 15.73710, reward_loss: 0.03352, value_loss: 0.69987 action_loss: 1.25379
# update_step:  32 model loss: 18.84496, kl_loss: 3.02871, obs_loss: 15.78016, reward_loss: 0.03609, value_loss: 0.51968 action_loss: 0.72164
# update_step:  33 model loss: 19.08644, kl_loss: 3.02902, obs_loss: 16.01702, reward_loss: 0.04040, value_loss: 0.65860 action_loss: 0.96070
# update_step:  34 model loss: 18.93277, kl_loss: 3.03078, obs_loss: 15.87342, reward_loss: 0.02857, value_loss: 0.68672 action_loss: 1.40504
# update_step:  35 model loss: 20.00046, kl_loss: 3.04463, obs_loss: 16.90742, reward_loss: 0.04841, value_loss: 0.86653 action_loss: 0.32312
# update_step:  36 model loss: 18.88195, kl_loss: 3.02982, obs_loss: 15.81329, reward_loss: 0.03884, value_loss: 0.92729 action_loss: 0.53459
# update_step:  37 model loss: 19.01862, kl_loss: 3.01918, obs_loss: 15.95898, reward_loss: 0.04046, value_loss: 0.82021 action_loss: 1.95849
# update_step:  38 model loss: 19.77467, kl_loss: 3.03493, obs_loss: 16.67504, reward_loss: 0.06470, value_loss: 1.20095 action_loss: 2.31612
# update_step:  39 model loss: 18.93054, kl_loss: 3.02620, obs_loss: 15.86737, reward_loss: 0.03696, value_loss: 0.59137 action_loss: 1.29040
# update_step:  40 model loss: 18.75597, kl_loss: 3.03217, obs_loss: 15.68722, reward_loss: 0.03657, value_loss: 1.19200 action_loss: 0.49654
# update_step:  41 model loss: 18.79642, kl_loss: 3.03182, obs_loss: 15.73152, reward_loss: 0.03309, value_loss: 2.14598 action_loss: -0.13268
# update_step:  42 model loss: 19.94566, kl_loss: 3.02808, obs_loss: 16.85987, reward_loss: 0.05771, value_loss: 2.84140 action_loss: -0.36933
# update_step:  43 model loss: 19.17985, kl_loss: 3.02728, obs_loss: 16.10774, reward_loss: 0.04483, value_loss: 1.75232 action_loss: -0.04201
# update_step:  44 model loss: 18.97725, kl_loss: 3.03657, obs_loss: 15.89682, reward_loss: 0.04387, value_loss: 0.99751 action_loss: 0.59263
# update_step:  45 model loss: 19.86716, kl_loss: 3.03278, obs_loss: 16.78016, reward_loss: 0.05422, value_loss: 0.96025 action_loss: 1.00895
# update_step:  46 model loss: 18.51860, kl_loss: 3.01996, obs_loss: 15.46802, reward_loss: 0.03062, value_loss: 0.98435 action_loss: 1.01279
# update_step:  47 model loss: 19.16357, kl_loss: 3.02321, obs_loss: 16.10463, reward_loss: 0.03573, value_loss: 1.09713 action_loss: 0.88016
# update_step:  48 model loss: 18.97710, kl_loss: 3.03930, obs_loss: 15.89899, reward_loss: 0.03881, value_loss: 0.85928 action_loss: 0.29973
# update_step:  49 model loss: 19.57609, kl_loss: 3.04354, obs_loss: 16.47330, reward_loss: 0.05924, value_loss: 0.70614 action_loss: 0.50797
# update_step:  50 model loss: 18.54759, kl_loss: 3.03361, obs_loss: 15.48250, reward_loss: 0.03148, value_loss: 1.20449 action_loss: 0.94115
# update_step:  51 model loss: 19.32039, kl_loss: 3.03572, obs_loss: 16.24146, reward_loss: 0.04321, value_loss: 0.64439 action_loss: 0.16363
# update_step:  52 model loss: 18.51809, kl_loss: 3.02269, obs_loss: 15.46450, reward_loss: 0.03090, value_loss: 0.83967 action_loss: 0.13622
# update_step:  53 model loss: 18.71196, kl_loss: 3.02449, obs_loss: 15.65434, reward_loss: 0.03314, value_loss: 1.17924 action_loss: 0.73843
# update_step:  54 model loss: 19.09183, kl_loss: 3.02731, obs_loss: 16.02081, reward_loss: 0.04372, value_loss: 1.13800 action_loss: 1.22062
# update_step:  55 model loss: 19.86946, kl_loss: 3.02588, obs_loss: 16.78907, reward_loss: 0.05450, value_loss: 0.70411 action_loss: -0.03925
# update_step:  56 model loss: 19.22263, kl_loss: 3.02784, obs_loss: 16.15363, reward_loss: 0.04116, value_loss: 0.87024 action_loss: 0.57911
# update_step:  57 model loss: 19.12613, kl_loss: 3.03248, obs_loss: 16.06201, reward_loss: 0.03164, value_loss: 2.05919 action_loss: 1.52716
# update_step:  58 model loss: 18.66662, kl_loss: 3.02919, obs_loss: 15.59893, reward_loss: 0.03850, value_loss: 2.28297 action_loss: 2.19583
# update_step:  59 model loss: 19.71137, kl_loss: 3.03292, obs_loss: 16.61434, reward_loss: 0.06412, value_loss: 0.74910 action_loss: 0.14143
# update_step:  60 model loss: 18.87883, kl_loss: 3.02366, obs_loss: 15.81376, reward_loss: 0.04142, value_loss: 1.42692 action_loss: -0.43798
# update_step:  61 model loss: 18.99453, kl_loss: 3.02453, obs_loss: 15.93170, reward_loss: 0.03830, value_loss: 0.97309 action_loss: 1.14034
# update_step:  62 model loss: 19.41688, kl_loss: 3.03898, obs_loss: 16.33824, reward_loss: 0.03966, value_loss: 0.88380 action_loss: 1.43884
# update_step:  63 model loss: 19.42006, kl_loss: 3.02699, obs_loss: 16.35257, reward_loss: 0.04050, value_loss: 0.63107 action_loss: 0.96229
# update_step:  64 model loss: 18.80574, kl_loss: 3.02206, obs_loss: 15.75208, reward_loss: 0.03159, value_loss: 0.49781 action_loss: 0.69157
# update_step:  65 model loss: 19.15996, kl_loss: 3.03080, obs_loss: 16.08780, reward_loss: 0.04135, value_loss: 0.53381 action_loss: 0.96102
# update_step:  66 model loss: 19.51110, kl_loss: 3.02258, obs_loss: 16.44580, reward_loss: 0.04272, value_loss: 1.08475 action_loss: 1.85755
# update_step:  67 model loss: 18.83780, kl_loss: 3.02626, obs_loss: 15.76680, reward_loss: 0.04474, value_loss: 0.79729 action_loss: 1.42829
# update_step:  68 model loss: 19.56250, kl_loss: 3.03025, obs_loss: 16.49440, reward_loss: 0.03785, value_loss: 0.77618 action_loss: 1.04681
# update_step:  69 model loss: 19.23277, kl_loss: 3.03552, obs_loss: 16.15586, reward_loss: 0.04140, value_loss: 0.68790 action_loss: 0.66002
# update_step:  70 model loss: 18.80465, kl_loss: 3.03445, obs_loss: 15.73663, reward_loss: 0.03356, value_loss: 0.80501 action_loss: 0.62455
# update_step:  71 model loss: 19.55281, kl_loss: 3.03323, obs_loss: 16.48470, reward_loss: 0.03487, value_loss: 1.22980 action_loss: 0.42749
# update_step:  72 model loss: 19.50641, kl_loss: 3.02438, obs_loss: 16.45029, reward_loss: 0.03174, value_loss: 1.17227 action_loss: 1.02962
# update_step:  73 model loss: 18.94540, kl_loss: 3.01669, obs_loss: 15.87731, reward_loss: 0.05140, value_loss: 0.70060 action_loss: 1.63120
# update_step:  74 model loss: 19.22558, kl_loss: 3.02312, obs_loss: 16.16513, reward_loss: 0.03734, value_loss: 0.60978 action_loss: 1.16606
# update_step:  75 model loss: 18.96700, kl_loss: 3.02685, obs_loss: 15.90546, reward_loss: 0.03469, value_loss: 0.68296 action_loss: 0.48456
# update_step:  76 model loss: 19.63353, kl_loss: 3.05595, obs_loss: 16.54424, reward_loss: 0.03334, value_loss: 1.04985 action_loss: -0.00714
# update_step:  77 model loss: 18.67400, kl_loss: 3.04059, obs_loss: 15.60229, reward_loss: 0.03113, value_loss: 0.85440 action_loss: 0.09859
# update_step:  78 model loss: 19.15755, kl_loss: 3.02933, obs_loss: 16.08320, reward_loss: 0.04503, value_loss: 0.80695 action_loss: 0.22254
# update_step:  79 model loss: 18.30209, kl_loss: 3.01967, obs_loss: 15.24446, reward_loss: 0.03796, value_loss: 0.81647 action_loss: -0.14407
# update_step:  80 model loss: 19.16891, kl_loss: 3.02882, obs_loss: 16.08617, reward_loss: 0.05392, value_loss: 0.63291 action_loss: 0.15431
# update_step:  81 model loss: 18.58917, kl_loss: 3.02235, obs_loss: 15.53866, reward_loss: 0.02816, value_loss: 0.69897 action_loss: 0.42634
# update_step:  82 model loss: 18.42644, kl_loss: 3.03097, obs_loss: 15.36243, reward_loss: 0.03303, value_loss: 0.56965 action_loss: 0.66296
# update_step:  83 model loss: 18.75801, kl_loss: 3.04585, obs_loss: 15.67751, reward_loss: 0.03465, value_loss: 0.89437 action_loss: -0.31799
# update_step:  84 model loss: 18.63132, kl_loss: 3.02864, obs_loss: 15.57227, reward_loss: 0.03042, value_loss: 1.11291 action_loss: -0.81429
# update_step:  85 model loss: 19.50122, kl_loss: 3.02913, obs_loss: 16.42893, reward_loss: 0.04316, value_loss: 0.78043 action_loss: -0.09900
# update_step:  86 model loss: 19.21419, kl_loss: 3.01801, obs_loss: 16.15244, reward_loss: 0.04374, value_loss: 0.88253 action_loss: 0.45271
# update_step:  87 model loss: 19.39697, kl_loss: 3.02698, obs_loss: 16.31687, reward_loss: 0.05312, value_loss: 0.57861 action_loss: -0.30507
# update_step:  88 model loss: 19.16194, kl_loss: 3.02894, obs_loss: 16.08453, reward_loss: 0.04847, value_loss: 0.68893 action_loss: -0.71091
# update_step:  89 model loss: 19.16594, kl_loss: 3.04725, obs_loss: 16.08336, reward_loss: 0.03534, value_loss: 0.63311 action_loss: -0.63847
# update_step:  90 model loss: 18.66375, kl_loss: 3.04156, obs_loss: 15.58699, reward_loss: 0.03520, value_loss: 1.04436 action_loss: -1.16461
# update_step:  91 model loss: 19.64624, kl_loss: 3.04011, obs_loss: 16.56582, reward_loss: 0.04031, value_loss: 1.06375 action_loss: -1.28174
# update_step:  92 model loss: 18.72178, kl_loss: 3.01887, obs_loss: 15.66329, reward_loss: 0.03962, value_loss: 0.68645 action_loss: -0.82106
# update_step:  93 model loss: 19.34154, kl_loss: 3.02401, obs_loss: 16.27469, reward_loss: 0.04284, value_loss: 0.73261 action_loss: -0.19099
# update_step:  94 model loss: 18.86867, kl_loss: 3.03089, obs_loss: 15.79384, reward_loss: 0.04394, value_loss: 0.62763 action_loss: -0.24501
# update_step:  95 model loss: 19.78189, kl_loss: 3.03472, obs_loss: 16.70506, reward_loss: 0.04211, value_loss: 0.83379 action_loss: -1.76984
# update_step:  96 model loss: 19.25419, kl_loss: 3.04469, obs_loss: 16.15132, reward_loss: 0.05818, value_loss: 0.52692 action_loss: -1.23424
# update_step:  97 model loss: 19.18876, kl_loss: 3.04570, obs_loss: 16.10666, reward_loss: 0.03641, value_loss: 1.00065 action_loss: -0.37259
# update_step:  98 model loss: 19.15500, kl_loss: 3.04871, obs_loss: 16.06131, reward_loss: 0.04498, value_loss: 0.79034 action_loss: -0.48313
# update_step:  99 model loss: 19.09786, kl_loss: 3.04011, obs_loss: 16.02430, reward_loss: 0.03345, value_loss: 0.62398 action_loss: -0.83935
# update_step: 100 model loss: 18.76271, kl_loss: 3.02674, obs_loss: 15.69296, reward_loss: 0.04301, value_loss: 0.91729 action_loss: -0.24112
# elasped time for update: 21.66s
# episode [ 142/ 200] is collected. Total reward is -159.219105
# elasped time for interaction: 1.86s
# update_step:   1 model loss: 18.67859, kl_loss: 3.03024, obs_loss: 15.61121, reward_loss: 0.03714, value_loss: 0.77109 action_loss: -0.45893
# update_step:   2 model loss: 19.16899, kl_loss: 3.02823, obs_loss: 16.09729, reward_loss: 0.04346, value_loss: 0.48526 action_loss: -0.88030
# update_step:   3 model loss: 19.45387, kl_loss: 3.04220, obs_loss: 16.34205, reward_loss: 0.06962, value_loss: 0.55152 action_loss: -0.96532
# update_step:   4 model loss: 19.40117, kl_loss: 3.05214, obs_loss: 16.28444, reward_loss: 0.06459, value_loss: 0.78488 action_loss: -0.41686
# update_step:   5 model loss: 18.92306, kl_loss: 3.02683, obs_loss: 15.86646, reward_loss: 0.02977, value_loss: 1.27189 action_loss: 0.36091
# update_step:   6 model loss: 18.61021, kl_loss: 3.02591, obs_loss: 15.54854, reward_loss: 0.03577, value_loss: 1.07481 action_loss: 0.39983
# update_step:   7 model loss: 20.04236, kl_loss: 3.06774, obs_loss: 16.88580, reward_loss: 0.08882, value_loss: 1.23838 action_loss: 0.79229
# update_step:   8 model loss: 19.84359, kl_loss: 3.03457, obs_loss: 16.75367, reward_loss: 0.05534, value_loss: 2.75413 action_loss: 1.92558
# update_step:   9 model loss: 19.14745, kl_loss: 3.02220, obs_loss: 16.08205, reward_loss: 0.04320, value_loss: 1.87956 action_loss: 1.84859
# update_step:  10 model loss: 18.05695, kl_loss: 3.01675, obs_loss: 15.00144, reward_loss: 0.03876, value_loss: 0.51578 action_loss: 0.73914
# update_step:  11 model loss: 19.61860, kl_loss: 3.03765, obs_loss: 16.49660, reward_loss: 0.08435, value_loss: 1.00436 action_loss: 1.26574
# update_step:  12 model loss: 18.74070, kl_loss: 3.04162, obs_loss: 15.65831, reward_loss: 0.04076, value_loss: 1.25639 action_loss: 0.03116
# update_step:  13 model loss: 18.74293, kl_loss: 3.02658, obs_loss: 15.65854, reward_loss: 0.05781, value_loss: 4.23389 action_loss: -1.77007

# %%
wandb.finish()

# %%
# %tensorboard --logdir='./logs'
# Out:
#       <iframe id="tensorboard-frame-46fcbc589f737eb6" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-46fcbc589f737eb6");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# 結果を動画で観てみるための関数
import matplotlib.pyplot as plt
from IPython.display import HTML
from matplotlib import animation


def display_video(frames: List[np.ndarray]) -> None:
    """
    結果を動画にするための関数．

    frames : List[np.ndarray]
        観測画像をリスト化したもの．
    """
    plt.figure(figsize=(8, 8), dpi=50)
    patch = plt.imshow(frames[0])
    plt.axis("off")

    def animate(i):
        patch.set_data(frames[i])
        plt.title("Step %d" % (i))

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    display(HTML(anim.to_jshtml(default_mode="once")))
    plt.close()

# %%
env = make_env()
policy = Agent(encoder, rssm.transition, action_model)
obs, obs_hand = env.reset()
terminated = False
total_reward = 0
frames = [obs]
for i in range(max_episodes):
    action = policy(obs, obs_hand, training=False)
    obs, obs_hand, reward, terminated, truncated, _ = env.step(action)
    total_reward += reward
    frames.append(obs)

print("Total Reward:", total_reward)
# Out:
# Total Reward: -269.122494482857

# %%
display_video(frames)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img01fae4cd098e4d86a20fe689b976b852">
#   <div class="anim-controls">
#     <input id="_anim_slider01fae4cd098e4d86a20fe689b976b852" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim01fae4cd098e4d86a20fe689b976b852.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim01fae4cd098e4d86a20fe689b976b852.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim01fae4cd098e4d86a20fe689b976b852.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim01fae4cd098e4d86a20fe689b976b852.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim01fae4cd098e4d86a20fe689b976b852.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim01fae4cd098e4d86a20fe689b976b852.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim01fae4cd098e4d86a20fe689b976b852.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim01fae4cd098e4d86a20fe689b976b852.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim01fae4cd098e4d86a20fe689b976b852.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim01fae4cd098e4d86a20fe689b976b852.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select01fae4cd098e4d86a20fe689b976b852"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_01fae4cd098e4d86a20fe689b976b852"
#              checked>
#       <label for="_anim_radio1_01fae4cd098e4d86a20fe689b976b852">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_01fae4cd098e4d86a20fe689b976b852"
#              >
#       <label for="_anim_radio2_01fae4cd098e4d86a20fe689b976b852">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_01fae4cd098e4d86a20fe689b976b852"
#              >
#       <label for="_anim_radio3_01fae4cd098e4d86a20fe689b976b852">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img01fae4cd098e4d86a20fe689b976b852";
#     var slider_id = "_anim_slider01fae4cd098e4d86a20fe689b976b852";
#     var loop_select_id = "_anim_loop_select01fae4cd098e4d86a20fe689b976b852";
#     var frames = new Array(51);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/GU6VOAAAACXBIWXMAAAex\
# AAAHsQEGxWGGAAAZD0lEQ

# %%
import matplotlib.pyplot as plt
from matplotlib import animation
import numpy as np

def save_video(frames: List[np.ndarray], filename: str = "output.mp4", fps: int = 20) -> None:
    """
    結果を動画に保存するための関数．

    frames : List[np.ndarray]
        観測画像をリスト化したもの．
    filename : str
        保存する動画のファイル名．デフォルトは "output.mp4"．
    fps : int
        動画のフレームレート．デフォルトは20．
    """
    plt.figure(figsize=(8, 8), dpi=50)
    patch = plt.imshow(frames[0])
    plt.axis("off")

    def animate(i):
        patch.set_data(frames[i])
        plt.title("Step %d" % (i))

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=1000/fps)

    # 動画を保存
    anim.save(filename, writer="ffmpeg", fps=fps)
    plt.close()

# %%
save_video(frames, "output-v0.3.2.mp4", fps=10)
